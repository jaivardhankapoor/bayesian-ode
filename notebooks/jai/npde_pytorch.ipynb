# %% [markdown]
# ### Import libraries

# %%
# import statements
# %load_ext autoreload
# %autoreload 2
# %cd "../../"

import torch 
from torch.autograd import Variable 
import torch.nn as nn
import torch.optim as optim

import warnings
warnings.filterwarnings('ignore')
with warnings.catch_warnings():
    warnings.simplefilter('ignore')
    

import numpy as np
import time

# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import matplotlib as mpl
import pickle
from scipy.cluster.vq import kmeans2
import scipy.stats as ss
from scipy.io import loadmat
# Out:
# /m/home/home5/56/kapoorj1/unix/repos/bayesian-ode

# %% [markdown]
# ### Generate data

# %%
# generate data
use_gpu = 1

class VDP(torch.nn.Module):
    def forward(self, t, x):
        return torch.cat([x[:,1:2], (1-x[:,0:1]**2)*x[:,1:2]-x[:,0:1]],1)

# from torchdiffeq import odeint_adjoint as odeint
from torchdiffeq import odeint

device = torch.device('cuda:' + str(use_gpu) if torch.cuda.is_available() else 'cpu')

N = 5
R = 3

x0 = torch.from_numpy(2*R*ss.uniform.rvs(size=[N,2])-R)
t = torch.linspace(0., 7., 40)

with torch.no_grad():
    X = odeint(VDP(), x0, t, method='rk4').numpy()
    X = np.transpose(X,[1,0,2])
    Y = X + ss.norm.rvs(size=X.shape)*0.1
    
plt.figure(1,[7,10])
for i in range(X.shape[0]):
    plt.plot(X[i,:,0],X[i,:,1],'-')

# %% [markdown]
# ## Implementation-1, gradients computed via sensitivities (uses autograd as a subroutine)

# %% [markdown]
# ### Initialize the model, parameters, variables, etc

# %%
# create variables, functions etc
M   = 6 # MxM inducing grid
D   = 2
sf  = 1
ell = 0.75

torch.set_default_tensor_type(torch.DoubleTensor)
xv = np.linspace(np.min([np.min(Y_[:,0]) for Y_ in Y]), np.max([np.max(Y_[:,0]) for Y_ in Y]), M)
yv = np.linspace(np.min([np.min(Y_[:,1]) for Y_ in Y]), np.max([np.max(Y_[:,1]) for Y_ in Y]), M)
xv,yv = np.meshgrid(xv,yv)
Z  = np.array([xv.T.flatten(),yv.T.flatten()]).T
Zt = torch.from_numpy(Z)
Yt = torch.from_numpy(Y)
U0 = 0.1*torch.randn(M*M, D)
# U0 = VDP().forward(0,Zt)

def _flatten(sequence):
    flat = [p.contiguous().view(-1) for p in sequence]
    return torch.cat(flat) if len(flat) > 0 else torch.tensor([])

def sq_dist(X1,X2):
    X1 = X1 / ell
    X1s = torch.sum(X1**2, dim=1).view([-1,1]) 
    X2 = X2 / ell
    X2s = torch.sum(X2**2, dim=1).view([1,-1])
    return -2*torch.mm(X1,torch.t(X2)) + X1s + X2s

def K(X1,X2):
    dist = sq_dist(X1,X2)
    return sf**2 * torch.exp(-dist / 2)

# gradient matching
F_ = (Yt[:,1:,:]-Yt[:,:-1,:]) / (t[1]-t[0])
F_ = F_.contiguous().view(-1,D)
Z_ = Yt[:,:-1,:].contiguous().view(-1,D)
Kxz = K(Zt,Z_)
Kzzinv = (K(Z_,Z_)+0.2*torch.eye(Z_.shape[0])).inverse()
U0 = torch.mm(torch.mm(Kxz,Kzzinv),F_) # not whitened
Linv = torch.cholesky(K(Zt,Zt)).inverse()
U0 = torch.mm(Linv,U0) # whitened

class KernelRegression(torch.nn.Module):
    def __init__(self):
        super(KernelRegression, self).__init__()
        self.U = torch.nn.Parameter(U0, requires_grad=True)
        self.Z = Zt
        self.Kzz = K(Zt,Zt)
        self.Kzzinv = self.Kzz.inverse()
        self.L = torch.cholesky(self.Kzz)
        self.KzzinvL = torch.mm(self.Kzzinv,self.L)

    def forward(self, t, X):
        T = torch.mm(K(X,self.Z),self.KzzinvL)
        return torch.mm(T,self.U)

class ODEINT_FS(torch.autograd.Function):
    @staticmethod
    def forward(ctx, func, x0, t, th):
        xode = odeint(func, x0, t, method='rk4').permute([1,0,2])
        ctx.func = func
        ctx.save_for_backward(x0,t,th,xode)
        return xode # N,T,D
    @staticmethod
    def backward(ctx, *grad_output): # grad_output[0] N,T,D ---> dL/dxode
        # print('backward')
        func = ctx.func
        x0,t,th,xode = ctx.saved_tensors
        N = x0.shape[0]  # problem dimensionality
        D = x0.shape[1]  # problem dimensionality
        MD = torch.numel(th) # number of parameters in the differential function
        with torch.no_grad():
            def ode_sens_rhs(t,xS): # xS = N,D,(1+MD)
                x = xS[:,:,0].view(-1,D) # N,D
                S = xS[:,:,1:] # N,D,MD
                th = list(func.parameters())[0]
                dxs = []
                dSs = []
                for j in range(N):
                    x_ = x[j:j+1].requires_grad_(True) #.detach() # 1,D
                    S_ = S[j] # D,MD
                    J = [] # accumulate columns of J here
                    R = [] # accumulate columns of R here
                    for i in range(D): # partial derivative of output dimension i 
                        with torch.set_grad_enabled(True):
                            f = func(t,x_)[0,i]
                            dfdxth = torch.autograd.grad(f, [x_,th], allow_unused=False, retain_graph=False)
                            J.append(dfdxth[0])
                            R.append(dfdxth[1].view(1,-1)) # 1,MD
                    J = torch.cat(J) # D,D
                    R = torch.cat(R) # D,MD
                    dS = torch.matmul(J,S_)+R # D,MD
                    dx = func(t,x_) # 1,D
                    dxs.append(dx.unsqueeze(2)) # 1,D,1
                    dSs.append(dS.unsqueeze(0)) # 1,D,MD
                dx = torch.cat(dxs) # N,D,1
                dS = torch.cat(dSs) # N,D,MD
                dxdS = torch.cat([dx,dS],2)
                return dxdS
            x0 = torch.unsqueeze(x0,2) # N,D,1
            S0 = torch.zeros(N,D,MD)
            xS0 = torch.cat((x0,S0),2) # N,D,(1+MD)
            xS = odeint(ode_sens_rhs, xS0, t, method='rk4') # T,N,D,(1+MD)
            xode2 = xS[:,:,:,0].permute([1,0,2]) # N,T,D
            # print('error between two ode integrations is {:f}'.format(torch.abs(xode-xode2).sum().numpy()))
            S = xS[:,:,:,1:].permute([1,2,0,3]) # N,D,T,MD
            # print(grad_output[0].shape) # N,T,D
            dlossdx = grad_output[0].permute([0,2,1]).unsqueeze(3) # N,D,T,1
            dlossdU = torch.sum(S*dlossdx,[0,1,2]) # MD
        return None,None,None,dlossdU # N,T,D
    
odeint_fs = ODEINT_FS.apply
kreg = KernelRegression()

# check why doesn't work
# from torch.autograd import gradcheck
# th_ = _flatten(kreg.parameters())
# test = gradcheck(odeint_fs, [kreg,x0,t,th_], eps=1e-6, atol=1e-4)
# print(test)

def odeint_forw_sens(func, x0, t):
    th = _flatten(func.parameters())
    xode = odeint_fs(kreg, x0, t, th)
    return xode

# %% [markdown]
# ### Optimize

# %%
# optimization

logsn = torch.nn.Parameter(torch.zeros(2), requires_grad=True)
params = [kreg.U,logsn]
optimizer = optim.Adam(params, lr=5e-3)

    
for itr in range(500):
    optimizer.zero_grad()
    T   = min(3+itr//10, len(t))
    t_  = t[:T]
    Yt_ = Yt[:,:T,:]
    xode = odeint_forw_sens(kreg,x0,t_)
    loss = torch.sum((Yt_-xode)**2 / torch.exp(logsn)**2) +  torch.numel(Yt_)*torch.sum(logsn)/D + \
        torch.sum(torch.diag(torch.mm(kreg.U.t(),kreg.U)))/2
    loss.backward()
    optimizer.step()

    if itr % 1 == 0:
        with torch.no_grad():
            xode = odeint_forw_sens(kreg,x0,t)
            loss = torch.sum((Yt-xode)**2 / torch.exp(logsn)**2) +  torch.numel(Yt)*torch.sum(logsn)/D
            print('Iter {:04d} | Total Loss {:.6f}'.format(itr, loss.item()))

    # break
    end = time.time()

# %% [markdown]
# ### Visualize

# %%
# plotting
xode = odeint_forw_sens(kreg, x0, t).detach().numpy()
U = kreg.U.detach().numpy()
Z = Zt.detach().numpy()

cols = ['r','b','g','m','c','k']
plt.figure(1,[7,10])
plt.scatter(Z[:,0],Z[:,1],100, facecolors='none', edgecolors='k')
plt.quiver(Z[:,0],Z[:,1],U[:,0],U[:,1],units='height',width=0.006,color='k')
for i in range(min(6,xode.shape[0])):
    plt.plot(X[i,:,0],X[i,:,1],'o',color=cols[i])
    plt.plot(xode[i,:,0],xode[i,:,1],'-',color=cols[i])

# %% [markdown]
# ## Implementation-2 that uses Torch autograd, no sensitivities/adjoints

# %% [markdown]
# ### Initialize the model, parameters, variables, etc

# %%
# create variables, functions etc
M   = 6 # MxM inducing grid
D   = 2
sf  = 1
ell = 0.75

torch.set_default_tensor_type(torch.DoubleTensor)
xv = np.linspace(np.min([np.min(Y_[:,0]) for Y_ in Y]), np.max([np.max(Y_[:,0]) for Y_ in Y]), M)
yv = np.linspace(np.min([np.min(Y_[:,1]) for Y_ in Y]), np.max([np.max(Y_[:,1]) for Y_ in Y]), M)
xv,yv = np.meshgrid(xv,yv)
Z  = np.array([xv.T.flatten(),yv.T.flatten()]).T
Zt = torch.from_numpy(Z)
Xt = torch.from_numpy(X)
U0 = 0.1*torch.randn(M*M, D)
# U0 = VDP().forward(0,Zt)

def sq_dist(X1,X2):
    X1 = X1 / ell
    X1s = torch.sum(X1**2, dim=1).view([-1,1]) 
    X2 = X2 / ell
    X2s = torch.sum(X2**2, dim=1).view([1,-1])
    return -2*torch.mm(X1,torch.t(X2)) + X1s + X2s

def K(X1,X2):
    dist = sq_dist(X1,X2)
    return sf**2 * torch.exp(-dist / 2)

# gradient matching
F_ = (Xt[:,1:,:]-Xt[:,:-1,:]) / (t[1]-t[0])
F_ = F_.contiguous().view(-1,D)
Z_ = Xt[:,:-1,:].contiguous().view(-1,D)
Kxz = K(Zt,Z_)
Kzzinv = (K(Z_,Z_)+0.2*torch.eye(Z_.shape[0])).inverse()
U0 = torch.mm(torch.mm(Kxz,Kzzinv),F_)


class KernelRegression(torch.nn.Module):
    def __init__(self):
        super(KernelRegression, self).__init__()
        self.U = torch.nn.Parameter(U0, requires_grad=True)
        self.logsn = torch.nn.Parameter(torch.zeros(2), requires_grad=True)
        self.Z = Zt

    def forward(self, t, X):
#         Z = self.Z
#         M = Z.shape[0]
#         N = X.shape[0]
#         A_LU = torch.lu(K(Z,Z).view(-1,M,M)) # 1,M,M
#         Kxz  = torch.t(K(X,Z)).view(-1,M,N)  # 1,M,N
#         A = torch.lu_solve(Kxz, *A_LU).view(M,N) # M x N
#         f = torch.mm(torch.t(A),self.U) # N x M
#         return f
#         Z = self.Z
#         Ltinv = torch.t(torch.cholesky(K(Z,Z))).inverse()
#         return torch.mm(torch.mm(K(X,Z),Ltinv),self.U)
        Z = self.Z
        Kzzinv = K(Z,Z).inverse()
        return torch.mm(torch.mm(K(X,Z),Kzzinv),self.U)

npode = KernelRegression()
lbfgs = optim.LBFGS(npode.parameters(), lr=1e-3)
# optimizer = optim.Adam(npode.parameters(), lr=5e-3)
optimizer = optim.SGD(npode.parameters(), lr=1e-5)

# %% [markdown]
# ### Optimize

# %%
# optimization
def closure():
    optimizer.zero_grad()
    xode = odeint(npode, x0, t).permute([1,0,2])
    loss = torch.mean((Xt-xode)**2 / torch.exp(npode.logsn))
    loss.backward()
    return loss
    
for itr in range(1000):
    optimizer.zero_grad()
    xode = odeint(npode, x0, t, method='rk4').permute([1,0,2])
    loss = torch.sum((Xt-xode)**2 / torch.exp(npode.logsn)**2) +  torch.numel(Xt)*torch.sum(npode.logsn)/D + \
        torch.sum(torch.diag(torch.mm(npode.U.t(),npode.U)))/2
    loss.backward()
    optimizer.step()
#     lbfgs.step(closure)

    if itr % 1 == 0:
        with torch.no_grad():
            xode = odeint(npode, x0, t, method='rk4').permute([1,0,2])
            loss = torch.mean((Xt-xode)**2 / torch.exp(npode.logsn))
            print('Iter {:04d} | Total Loss {:.6f}'.format(itr, loss.item()))

    end = time.time()
# Out:
# Iter 0000 | Total Loss 0.450096
# Iter 0001 | Total Loss 0.441300
# Iter 0002 | Total Loss 0.432583
# Iter 0003 | Total Loss 0.423944
# Iter 0004 | Total Loss 0.415386
# Iter 0005 | Total Loss 0.406909
# Iter 0006 | Total Loss 0.398513
# Iter 0007 | Total Loss 0.390201
# Iter 0008 | Total Loss 0.381972
# Iter 0009 | Total Loss 0.373829
# Iter 0010 | Total Loss 0.365772
# Iter 0011 | Total Loss 0.357803
# Iter 0012 | Total Loss 0.349923
# Iter 0013 | Total Loss 0.342134
# Iter 0014 | Total Loss 0.334436
# Iter 0015 | Total Loss 0.326831
# Iter 0016 | Total Loss 0.319320
# Iter 0017 | Total Loss 0.311905
# Iter 0018 | Total Loss 0.304587
# Iter 0019 | Total Loss 0.297368
# Iter 0020 | Total Loss 0.290249
# Iter 0021 | Total Loss 0.283232
# Iter 0022 | Total Loss 0.276317
# Iter 0023 | Total Loss 0.269506
# Iter 0024 | Total Loss 0.262801
# Iter 0025 | Total Loss 0.256203
# Iter 0026 | Total Loss 0.249713
# Iter 0027 | Total Loss 0.243333
# Iter 0028 | Total Loss 0.237063
# Iter 0029 | Total Loss 0.230906
# Iter 0030 | Total Loss 0.224863
# Iter 0031 | Total Loss 0.218934
# Iter 0032 | Total Loss 0.213121
# Iter 0033 | Total Loss 0.207424
# Iter 0034 | Total Loss 0.201846
# Iter 0035 | Total Loss 0.196387
# Iter 0036 | Total Loss 0.191048
# Iter 0037 | Total Loss 0.185830
# Iter 0038 | Total Loss 0.180733
# Iter 0039 | Total Loss 0.175758
# Iter 0040 | Total Loss 0.170905
# Iter 0041 | Total Loss 0.166176
# Iter 0042 | Total Loss 0.161571
# Iter 0043 | Total Loss 0.157089
# Iter 0044 | Total Loss 0.152730
# Iter 0045 | Total Loss 0.148496
# Iter 0046 | Total Loss 0.144385
# Iter 0047 | Total Loss 0.140397
# Iter 0048 | Total Loss 0.136532
# Iter 0049 | Total Loss 0.132789
# Iter 0050 | Total Loss 0.129168
# Iter 0051 | Total Loss 0.125667
# Iter 0052 | Total Loss 0.122286
# Iter 0053 | Total Loss 0.119023
# Iter 0054 | Total Loss 0.115877
# Iter 0055 | Total Loss 0.112847
# Iter 0056 | Total Loss 0.109931
# Iter 0057 | Total Loss 0.107127
# Iter 0058 | Total Loss 0.104433
# Iter 0059 | Total Loss 0.101848
# Iter 0060 | Total Loss 0.099370
# Iter 0061 | Total Loss 0.096995
# Iter 0062 | Total Loss 0.094722
# Iter 0063 | Total Loss 0.092549
# Iter 0064 | Total Loss 0.090472
# Iter 0065 | Total Loss 0.088489
# Iter 0066 | Total Loss 0.086599
# Iter 0067 | Total Loss 0.084797
# Iter 0068 | Total Loss 0.083081
# Iter 0069 | Total Loss 0.081449
# Iter 0070 | Total Loss 0.079897
# Iter 0071 | Total Loss 0.078424
# Iter 0072 | Total Loss 0.077025
# Iter 0073 | Total Loss 0.075698
# Iter 0074 | Total Loss 0.074441
# Iter 0075 | Total Loss 0.073250
# Iter 0076 | Total Loss 0.072123
# Iter 0077 | Total Loss 0.071058
# Iter 0078 | Total Loss 0.070050
# Iter 0079 | Total Loss 0.069098
# Iter 0080 | Total Loss 0.068200
# Iter 0081 | Total Loss 0.067352
# Iter 0082 | Total Loss 0.066552
# Iter 0083 | Total Loss 0.065798
# Iter 0084 | Total Loss 0.065087
# Iter 0085 | Total Loss 0.064417
# Iter 0086 | Total Loss 0.063787
# Iter 0087 | Total Loss 0.063193
# Iter 0088 | Total Loss 0.062634
# Iter 0089 | Total Loss 0.062108
# Iter 0090 | Total Loss 0.061612
# Iter 0091 | Total Loss 0.061147
# Iter 0092 | Total Loss 0.060708
# Iter 0093 | Total Loss 0.060296
# Iter 0094 | Total Loss 0.059907
# Iter 0095 | Total Loss 0.059542
# Iter 0096 | Total Loss 0.059198
# Iter 0097 | Total Loss 0.058874
# Iter 0098 | Total Loss 0.058569
# Iter 0099 | Total Loss 0.058281
# Iter 0100 | Total Loss 0.058010
# Iter 0101 | Total Loss 0.057754
# Iter 0102 | Total Loss 0.057513
# Iter 0103 | Total Loss 0.057285
# Iter 0104 | Total Loss 0.057070
# Iter 0105 | Total Loss 0.056867
# Iter 0106 | Total Loss 0.056674
# Iter 0107 | Total Loss 0.056492
# Iter 0108 | Total Loss 0.056319
# Iter 0109 | Total Loss 0.056155
# Iter 0110 | Total Loss 0.056000
# Iter 0111 | Total Loss 0.055852
# Iter 0112 | Total Loss 0.055711
# Iter 0113 | Total Loss 0.055577
# Iter 0114 | Total Loss 0.055449
# Iter 0115 | Total Loss 0.055327
# Iter 0116 | Total Loss 0.055210
# Iter 0117 | Total Loss 0.055099
# Iter 0118 | Total Loss 0.054992
# Iter 0119 | Total Loss 0.054890
# Iter 0120 | Total Loss 0.054791
# Iter 0121 | Total Loss 0.054697
# Iter 0122 | Total Loss 0.054606
# Iter 0123 | Total Loss 0.054518
# Iter 0124 | Total Loss 0.054434
# Iter 0125 | Total Loss 0.054352
# Iter 0126 | Total Loss 0.054273
# Iter 0127 | Total Loss 0.054197
# Iter 0128 | Total Loss 0.054123
# Iter 0129 | Total Loss 0.054051
# Iter 0130 | Total Loss 0.053982
# Iter 0131 | Total Loss 0.053914
# Iter 0132 | Total Loss 0.053849
# Iter 0133 | Total Loss 0.053785
# Iter 0134 | Total Loss 0.053722
# Iter 0135 | Total Loss 0.053662
# Iter 0136 | Total Loss 0.053602
# Iter 0137 | Total Loss 0.053544
# Iter 0138 | Total Loss 0.053488
# Iter 0139 | Total Loss 0.053432
# Iter 0140 | Total Loss 0.053378
# Iter 0141 | Total Loss 0.053325
# Iter 0142 | Total Loss 0.053273
# Iter 0143 | Total Loss 0.053222
# Iter 0144 | Total Loss 0.053172
# Iter 0145 | Total Loss 0.053123
# Iter 0146 | Total Loss 0.053075
# Iter 0147 | Total Loss 0.053028
# Iter 0148 | Total Loss 0.052981
# Iter 0149 | Total Loss 0.052936
# Iter 0150 | Total Loss 0.052891
# Iter 0151 | Total Loss 0.052846
# Iter 0152 | Total Loss 0.052803
# Iter 0153 | Total Loss 0.052760
# Iter 0154 | Total Loss 0.052717
# Iter 0155 | Total Loss 0.052676
# Iter 0156 | Total Loss 0.052635
# Iter 0157 | Total Loss 0.052594
# Iter 0158 | Total Loss 0.052554
# Iter 0159 | Total Loss 0.052514
# Iter 0160 | Total Loss 0.052475
# Iter 0161 | Total Loss 0.052437
# Iter 0162 | Total Loss 0.052399
# Iter 0163 | Total Loss 0.052361
# Iter 0164 | Total Loss 0.052324
# Iter 0165 | Total Loss 0.052287
# Iter 0166 | Total Loss 0.052251
# Iter 0167 | Total Loss 0.052215
# Iter 0168 | Total Loss 0.052180
# Iter 0169 | Total Loss 0.052145
# Iter 0170 | Total Loss 0.052110
# Iter 0171 | Total Loss 0.052076
# Iter 0172 | Total Loss 0.052042
# Iter 0173 | Total Loss 0.052008
# Iter 0174 | Total Loss 0.051975
# Iter 0175 | Total Loss 0.051942
# Iter 0176 | Total Loss 0.051909
# Iter 0177 | Total Loss 0.051876
# Iter 0178 | Total Loss 0.051844
# Iter 0179 | Total Loss 0.051813
# Iter 0180 | Total Loss 0.051781
# Iter 0181 | Total Loss 0.051750
# Iter 0182 | Total Loss 0.051719
# Iter 0183 | Total Loss 0.051688
# Iter 0184 | Total Loss 0.051658
# Iter 0185 | Total Loss 0.051628
# Iter 0186 | Total Loss 0.051598
# Iter 0187 | Total Loss 0.051568
# Iter 0188 | Total Loss 0.051539
# Iter 0189 | Total Loss 0.051509
# Iter 0190 | Total Loss 0.051480
# Iter 0191 | Total Loss 0.051452
# Iter 0192 | Total Loss 0.051423
# Iter 0193 | Total Loss 0.051395
# Iter 0194 | Total Loss 0.051367
# Iter 0195 | Total Loss 0.051339
# Iter 0196 | Total Loss 0.051311
# Iter 0197 | Total Loss 0.051283
# Iter 0198 | Total Loss 0.051256
# Iter 0199 | Total Loss 0.051229
# Iter 0200 | Total Loss 0.051202
# Iter 0201 | Total Loss 0.051175
# Iter 0202 | Total Loss 0.051149
# Iter 0203 | Total Loss 0.051122
# Iter 0204 | Total Loss 0.051096
# Iter 0205 | Total Loss 0.051070
# Iter 0206 | Total Loss 0.051044
# Iter 0207 | Total Loss 0.051018
# Iter 0208 | Total Loss 0.050993
# Iter 0209 | Total Loss 0.050967
# Iter 0210 | Total Loss 0.050942
# Iter 0211 | Total Loss 0.050917
# Iter 0212 | Total Loss 0.050892
# Iter 0213 | Total Loss 0.050867
# Iter 0214 | Total Loss 0.050843
# Iter 0215 | Total Loss 0.050818
# Iter 0216 | Total Loss 0.050794
# Iter 0217 | Total Loss 0.050770
# Iter 0218 | Total Loss 0.050746
# Iter 0219 | Total Loss 0.050722
# Iter 0220 | Total Loss 0.050698
# Iter 0221 | Total Loss 0.050674
# Iter 0222 | Total Loss 0.050651
# Iter 0223 | Total Loss 0.050628
# Iter 0224 | Total Loss 0.050604
# Iter 0225 | Total Loss 0.050581
# Iter 0226 | Total Loss 0.050558
# Iter 0227 | Total Loss 0.050535
# Iter 0228 | Total Loss 0.050513
# Iter 0229 | Total Loss 0.050490
# Iter 0230 | Total Loss 0.050468
# Iter 0231 | Total Loss 0.050446
# Iter 0232 | Total Loss 0.050423
# Iter 0233 | Total Loss 0.050401
# Iter 0234 | Total Loss 0.050379
# Iter 0235 | Total Loss 0.050358
# Iter 0236 | Total Loss 0.050336
# Iter 0237 | Total Loss 0.050314
# Iter 0238 | Total Loss 0.050293
# Iter 0239 | Total Loss 0.050272
# Iter 0240 | Total Loss 0.050250
# Iter 0241 | Total Loss 0.050229
# Iter 0242 | Total Loss 0.050208
# Iter 0243 | Total Loss 0.050188
# Iter 0244 | Total Loss 0.050167
# Iter 0245 | Total Loss 0.050146
# Iter 0246 | Total Loss 0.050126
# Iter 0247 | Total Loss 0.050106
# Iter 0248 | Total Loss 0.050085
# Iter 0249 | Total Loss 0.050065
# Iter 0250 | Total Loss 0.050045
# Iter 0251 | Total Loss 0.050025
# Iter 0252 | Total Loss 0.050006
# Iter 0253 | Total Loss 0.049986
# Iter 0254 | Total Loss 0.049967
# Iter 0255 | Total Loss 0.049947
# Iter 0256 | Total Loss 0.049928
# Iter 0257 | Total Loss 0.049909
# Iter 0258 | Total Loss 0.049890
# Iter 0259 | Total Loss 0.049871
# Iter 0260 | Total Loss 0.049852
# Iter 0261 | Total Loss 0.049833
# Iter 0262 | Total Loss 0.049815
# Iter 0263 | Total Loss 0.049796
# Iter 0264 | Total Loss 0.049778
# Iter 0265 | Total Loss 0.049760
# Iter 0266 | Total Loss 0.049742
# Iter 0267 | Total Loss 0.049724
# Iter 0268 | Total Loss 0.049706
# Iter 0269 | Total Loss 0.049688
# Iter 0270 | Total Loss 0.049671
# Iter 0271 | Total Loss 0.049653
# Iter 0272 | Total Loss 0.049636
# Iter 0273 | Total Loss 0.049619
# Iter 0274 | Total Loss 0.049601
# Iter 0275 | Total Loss 0.049584
# Iter 0276 | Total Loss 0.049568
# Iter 0277 | Total Loss 0.049551
# Iter 0278 | Total Loss 0.049534
# Iter 0279 | Total Loss 0.049518
# Iter 0280 | Total Loss 0.049501
# Iter 0281 | Total Loss 0.049485
# Iter 0282 | Total Loss 0.049469
# Iter 0283 | Total Loss 0.049453
# Iter 0284 | Total Loss 0.049437
# Iter 0285 | Total Loss 0.049421
# Iter 0286 | Total Loss 0.049405
# Iter 0287 | Total Loss 0.049390
# Iter 0288 | Total Loss 0.049374
# Iter 0289 | Total Loss 0.049359
# Iter 0290 | Total Loss 0.049344
# Iter 0291 | Total Loss 0.049329
# Iter 0292 | Total Loss 0.049314
# Iter 0293 | Total Loss 0.049299
# Iter 0294 | Total Loss 0.049284
# Iter 0295 | Total Loss 0.049269
# Iter 0296 | Total Loss 0.049255
# Iter 0297 | Total Loss 0.049241
# Iter 0298 | Total Loss 0.049226
# Iter 0299 | Total Loss 0.049212
# Iter 0300 | Total Loss 0.049198
# Iter 0301 | Total Loss 0.049184
# Iter 0302 | Total Loss 0.049171
# Iter 0303 | Total Loss 0.049157
# Iter 0304 | Total Loss 0.049143
# Iter 0305 | Total Loss 0.049130
# Iter 0306 | Total Loss 0.049117
# Iter 0307 | Total Loss 0.049104
# Iter 0308 | Total Loss 0.049091
# Iter 0309 | Total Loss 0.049078
# Iter 0310 | Total Loss 0.049065
# Iter 0311 | Total Loss 0.049052
# Iter 0312 | Total Loss 0.049040
# Iter 0313 | Total Loss 0.049027
# Iter 0314 | Total Loss 0.049015
# Iter 0315 | Total Loss 0.049003
# Iter 0316 | Total Loss 0.048991
# Iter 0317 | Total Loss 0.048979
# Iter 0318 | Total Loss 0.048967
# Iter 0319 | Total Loss 0.048956
# Iter 0320 | Total Loss 0.048944
# Iter 0321 | Total Loss 0.048933
# Iter 0322 | Total Loss 0.048922
# Iter 0323 | Total Loss 0.048910
# Iter 0324 | Total Loss 0.048899
# Iter 0325 | Total Loss 0.048888
# Iter 0326 | Total Loss 0.048878
# Iter 0327 | Total Loss 0.048867
# Iter 0328 | Total Loss 0.048856
# Iter 0329 | Total Loss 0.048846
# Iter 0330 | Total Loss 0.048836
# Iter 0331 | Total Loss 0.048826
# Iter 0332 | Total Loss 0.048816
# Iter 0333 | Total Loss 0.048806
# Iter 0334 | Total Loss 0.048796
# Iter 0335 | Total Loss 0.048786
# Iter 0336 | Total Loss 0.048777
# Iter 0337 | Total Loss 0.048767
# Iter 0338 | Total Loss 0.048758
# Iter 0339 | Total Loss 0.048749
# Iter 0340 | Total Loss 0.048740
# Iter 0341 | Total Loss 0.048731
# Iter 0342 | Total Loss 0.048722
# Iter 0343 | Total Loss 0.048713
# Iter 0344 | Total Loss 0.048705
# Iter 0345 | Total Loss 0.048696
# Iter 0346 | Total Loss 0.048688
# Iter 0347 | Total Loss 0.048680
# Iter 0348 | Total Loss 0.048672
# Iter 0349 | Total Loss 0.048664
# Iter 0350 | Total Loss 0.048656
# Iter 0351 | Total Loss 0.048648
# Iter 0352 | Total Loss 0.048641
# Iter 0353 | Total Loss 0.048633
# Iter 0354 | Total Loss 0.048626
# Iter 0355 | Total Loss 0.048619
# Iter 0356 | Total Loss 0.048612
# Iter 0357 | Total Loss 0.048605
# Iter 0358 | Total Loss 0.048598
# Iter 0359 | Total Loss 0.048591
# Iter 0360 | Total Loss 0.048584
# Iter 0361 | Total Loss 0.048578
# Iter 0362 | Total Loss 0.048572
# Iter 0363 | Total Loss 0.048565
# Iter 0364 | Total Loss 0.048559
# Iter 0365 | Total Loss 0.048553
# Iter 0366 | Total Loss 0.048547
# Iter 0367 | Total Loss 0.048542
# Iter 0368 | Total Loss 0.048536
# Iter 0369 | Total Loss 0.048530
# Iter 0370 | Total Loss 0.048525
# Iter 0371 | Total Loss 0.048520
# Iter 0372 | Total Loss 0.048514
# Iter 0373 | Total Loss 0.048509
# Iter 0374 | Total Loss 0.048505
# Iter 0375 | Total Loss 0.048500
# Iter 0376 | Total Loss 0.048495
# Iter 0377 | Total Loss 0.048490
# Iter 0378 | Total Loss 0.048486
# Iter 0379 | Total Loss 0.048482
# Iter 0380 | Total Loss 0.048477
# Iter 0381 | Total Loss 0.048473
# Iter 0382 | Total Loss 0.048469
# Iter 0383 | Total Loss 0.048465
# Iter 0384 | Total Loss 0.048462
# Iter 0385 | Total Loss 0.048458
# Iter 0386 | Total Loss 0.048454
# Iter 0387 | Total Loss 0.048451
# Iter 0388 | Total Loss 0.048448
# Iter 0389 | Total Loss 0.048445
# Iter 0390 | Total Loss 0.048442
# Iter 0391 | Total Loss 0.048439
# Iter 0392 | Total Loss 0.048436
# Iter 0393 | Total Loss 0.048433
# Iter 0394 | Total Loss 0.048430
# Iter 0395 | Total Loss 0.048428
# Iter 0396 | Total Loss 0.048425
# Iter 0397 | Total Loss 0.048423
# Iter 0398 | Total Loss 0.048421
# Iter 0399 | Total Loss 0.048419
# Iter 0400 | Total Loss 0.048417
# Iter 0401 | Total Loss 0.048415
# Iter 0402 | Total Loss 0.048413
# Iter 0403 | Total Loss 0.048412
# Iter 0404 | Total Loss 0.048410
# Iter 0405 | Total Loss 0.048409
# Iter 0406 | Total Loss 0.048408
# Iter 0407 | Total Loss 0.048406
# Iter 0408 | Total Loss 0.048405
# Iter 0409 | Total Loss 0.048404
# Iter 0410 | Total Loss 0.048404
# Iter 0411 | Total Loss 0.048403
# Iter 0412 | Total Loss 0.048402
# Iter 0413 | Total Loss 0.048402
# Iter 0414 | Total Loss 0.048401
# Iter 0415 | Total Loss 0.048401
# Iter 0416 | Total Loss 0.048401
# Iter 0417 | Total Loss 0.048401
# Iter 0418 | Total Loss 0.048401
# Iter 0419 | Total Loss 0.048401
# Iter 0420 | Total Loss 0.048401
# Iter 0421 | Total Loss 0.048401
# Iter 0422 | Total Loss 0.048402
# Iter 0423 | Total Loss 0.048402
# Iter 0424 | Total Loss 0.048403
# Iter 0425 | Total Loss 0.048404
# Iter 0426 | Total Loss 0.048404
# Iter 0427 | Total Loss 0.048405
# Iter 0428 | Total Loss 0.048406
# Iter 0429 | Total Loss 0.048408
# Iter 0430 | Total Loss 0.048409
# Iter 0431 | Total Loss 0.048410
# Iter 0432 | Total Loss 0.048412
# Iter 0433 | Total Loss 0.048413
# Iter 0434 | Total Loss 0.048415
# Iter 0435 | Total Loss 0.048416
# Iter 0436 | Total Loss 0.048418
# Iter 0437 | Total Loss 0.048420
# Iter 0438 | Total Loss 0.048422
# Iter 0439 | Total Loss 0.048424
# Iter 0440 | Total Loss 0.048427
# Iter 0441 | Total Loss 0.048429
# Iter 0442 | Total Loss 0.048431
# Iter 0443 | Total Loss 0.048434
# Iter 0444 | Total Loss 0.048436
# Iter 0445 | Total Loss 0.048439
# Iter 0446 | Total Loss 0.048442
# Iter 0447 | Total Loss 0.048445
# Iter 0448 | Total Loss 0.048448
# Iter 0449 | Total Loss 0.048451
# Iter 0450 | Total Loss 0.048454
# Iter 0451 | Total Loss 0.048457
# Iter 0452 | Total Loss 0.048461
# Iter 0453 | Total Loss 0.048464
# Iter 0454 | Total Loss 0.048468
# Iter 0455 | Total Loss 0.048471
# Iter 0456 | Total Loss 0.048475
# Iter 0457 | Total Loss 0.048479
# Iter 0458 | Total Loss 0.048483
# Iter 0459 | Total Loss 0.048487
# Iter 0460 | Total Loss 0.048491
# Iter 0461 | Total Loss 0.048495
# Iter 0462 | Total Loss 0.048499
# Iter 0463 | Total Loss 0.048503
# Iter 0464 | Total Loss 0.048508
# Iter 0465 | Total Loss 0.048512
# Iter 0466 | Total Loss 0.048517
# Iter 0467 | Total Loss 0.048522
# Iter 0468 | Total Loss 0.048526
# Iter 0469 | Total Loss 0.048531
# Iter 0470 | Total Loss 0.048536
# Iter 0471 | Total Loss 0.048541
# Iter 0472 | Total Loss 0.048546
# Iter 0473 | Total Loss 0.048552
# Iter 0474 | Total Loss 0.048557
# Iter 0475 | Total Loss 0.048562
# Iter 0476 | Total Loss 0.048568
# Iter 0477 | Total Loss 0.048573
# Iter 0478 | Total Loss 0.048579
# Iter 0479 | Total Loss 0.048584
# Iter 0480 | Total Loss 0.048590
# Iter 0481 | Total Loss 0.048596
# Iter 0482 | Total Loss 0.048602
# Iter 0483 | Total Loss 0.048608
# Iter 0484 | Total Loss 0.048614
# Iter 0485 | Total Loss 0.048620
# Iter 0486 | Total Loss 0.048626
# Iter 0487 | Total Loss 0.048633
# Iter 0488 | Total Loss 0.048639
# Iter 0489 | Total Loss 0.048646
# Iter 0490 | Total Loss 0.048652
# Iter 0491 | Total Loss 0.048659
# Iter 0492 | Total Loss 0.048665
# Iter 0493 | Total Loss 0.048672
# Iter 0494 | Total Loss 0.048679
# Iter 0495 | Total Loss 0.048686
# Iter 0496 | Total Loss 0.048693
# Iter 0497 | Total Loss 0.048700
# Iter 0498 | Total Loss 0.048707
# Iter 0499 | Total Loss 0.048714
# Iter 0500 | Total Loss 0.048722
# Iter 0501 | Total Loss 0.048729
# Iter 0502 | Total Loss 0.048736
# Iter 0503 | Total Loss 0.048744
# Iter 0504 | Total Loss 0.048751
# Iter 0505 | Total Loss 0.048759
# Iter 0506 | Total Loss 0.048767
# Iter 0507 | Total Loss 0.048775
# Iter 0508 | Total Loss 0.048782
# Iter 0509 | Total Loss 0.048790
# Iter 0510 | Total Loss 0.048798
# Iter 0511 | Total Loss 0.048806
# Iter 0512 | Total Loss 0.048814
# Iter 0513 | Total Loss 0.048823
# Iter 0514 | Total Loss 0.048831
# Iter 0515 | Total Loss 0.048839
# Iter 0516 | Total Loss 0.048848
# Iter 0517 | Total Loss 0.048856
# Iter 0518 | Total Loss 0.048864
# Iter 0519 | Total Loss 0.048873
# Iter 0520 | Total Loss 0.048882
# Iter 0521 | Total Loss 0.048890
# Iter 0522 | Total Loss 0.048899
# Iter 0523 | Total Loss 0.048908
# Iter 0524 | Total Loss 0.048917
# Iter 0525 | Total Loss 0.048926
# Iter 0526 | Total Loss 0.048935
# Iter 0527 | Total Loss 0.048944
# Iter 0528 | Total Loss 0.048953
# Iter 0529 | Total Loss 0.048962
# Iter 0530 | Total Loss 0.048971
# Iter 0531 | Total Loss 0.048980
# Iter 0532 | Total Loss 0.048990
# Iter 0533 | Total Loss 0.048999
# Iter 0534 | Total Loss 0.049009
# Iter 0535 | Total Loss 0.049018
# Iter 0536 | Total Loss 0.049028
# Iter 0537 | Total Loss 0.049037
# Iter 0538 | Total Loss 0.049047
# Iter 0539 | Total Loss 0.049057
# Iter 0540 | Total Loss 0.049067
# Iter 0541 | Total Loss 0.049076
# Iter 0542 | Total Loss 0.049086
# Iter 0543 | Total Loss 0.049096
# Iter 0544 | Total Loss 0.049106
# Iter 0545 | Total Loss 0.049116
# Iter 0546 | Total Loss 0.049126
# Iter 0547 | Total Loss 0.049137
# Iter 0548 | Total Loss 0.049147
# Iter 0549 | Total Loss 0.049157
# Iter 0550 | Total Loss 0.049167
# Iter 0551 | Total Loss 0.049178
# Iter 0552 | Total Loss 0.049188
# Iter 0553 | Total Loss 0.049198
# Iter 0554 | Total Loss 0.049209
# Iter 0555 | Total Loss 0.049220
# Iter 0556 | Total Loss 0.049230
# Iter 0557 | Total Loss 0.049241
# Iter 0558 | Total Loss 0.049251
# Iter 0559 | Total Loss 0.049262
# Iter 0560 | Total Loss 0.049273
# Iter 0561 | Total Loss 0.049284
# Iter 0562 | Total Loss 0.049295
# Iter 0563 | Total Loss 0.049306
# Iter 0564 | Total Loss 0.049317
# Iter 0565 | Total Loss 0.049328
# Iter 0566 | Total Loss 0.049339
# Iter 0567 | Total Loss 0.049350
# Iter 0568 | Total Loss 0.049361
# Iter 0569 | Total Loss 0.049372
# Iter 0570 | Total Loss 0.049383
# Iter 0571 | Total Loss 0.049394
# Iter 0572 | Total Loss 0.049406
# Iter 0573 | Total Loss 0.049417
# Iter 0574 | Total Loss 0.049428
# Iter 0575 | Total Loss 0.049440
# Iter 0576 | Total Loss 0.049451
# Iter 0577 | Total Loss 0.049463
# Iter 0578 | Total Loss 0.049474
# Iter 0579 | Total Loss 0.049486
# Iter 0580 | Total Loss 0.049497
# Iter 0581 | Total Loss 0.049509
# Iter 0582 | Total Loss 0.049521
# Iter 0583 | Total Loss 0.049532
# Iter 0584 | Total Loss 0.049544
# Iter 0585 | Total Loss 0.049556
# Iter 0586 | Total Loss 0.049568
# Iter 0587 | Total Loss 0.049580
# Iter 0588 | Total Loss 0.049591
# Iter 0589 | Total Loss 0.049603
# Iter 0590 | Total Loss 0.049615
# Iter 0591 | Total Loss 0.049627
# Iter 0592 | Total Loss 0.049639
# Iter 0593 | Total Loss 0.049651
# Iter 0594 | Total Loss 0.049663
# Iter 0595 | Total Loss 0.049676
# Iter 0596 | Total Loss 0.049688
# Iter 0597 | Total Loss 0.049700
# Iter 0598 | Total Loss 0.049712
# Iter 0599 | Total Loss 0.049724
# Iter 0600 | Total Loss 0.049736
# Iter 0601 | Total Loss 0.049749
# Iter 0602 | Total Loss 0.049761
# Iter 0603 | Total Loss 0.049773
# Iter 0604 | Total Loss 0.049786
# Iter 0605 | Total Loss 0.049798
# Iter 0606 | Total Loss 0.049811
# Iter 0607 | Total Loss 0.049823
# Iter 0608 | Total Loss 0.049835
# Iter 0609 | Total Loss 0.049848
# Iter 0610 | Total Loss 0.049860
# Iter 0611 | Total Loss 0.049873
# Iter 0612 | Total Loss 0.049886
# Iter 0613 | Total Loss 0.049898
# Iter 0614 | Total Loss 0.049911
# Iter 0615 | Total Loss 0.049923
# Iter 0616 | Total Loss 0.049936
# Iter 0617 | Total Loss 0.049949
# Iter 0618 | Total Loss 0.049961
# Iter 0619 | Total Loss 0.049974
# Iter 0620 | Total Loss 0.049987
# Iter 0621 | Total Loss 0.050000
# Iter 0622 | Total Loss 0.050012
# Iter 0623 | Total Loss 0.050025
# Iter 0624 | Total Loss 0.050038
# Iter 0625 | Total Loss 0.050051
# Iter 0626 | Total Loss 0.050064
# Iter 0627 | Total Loss 0.050076
# Iter 0628 | Total Loss 0.050089
# Iter 0629 | Total Loss 0.050102
# Iter 0630 | Total Loss 0.050115
# Iter 0631 | Total Loss 0.050128
# Iter 0632 | Total Loss 0.050141
# Iter 0633 | Total Loss 0.050154
# Iter 0634 | Total Loss 0.050167
# Iter 0635 | Total Loss 0.050180
# Iter 0636 | Total Loss 0.050193
# Iter 0637 | Total Loss 0.050206
# Iter 0638 | Total Loss 0.050219
# Iter 0639 | Total Loss 0.050232
# Iter 0640 | Total Loss 0.050245
# Iter 0641 | Total Loss 0.050258
# Iter 0642 | Total Loss 0.050271
# Iter 0643 | Total Loss 0.050285
# Iter 0644 | Total Loss 0.050298
# Iter 0645 | Total Loss 0.050311
# Iter 0646 | Total Loss 0.050324
# Iter 0647 | Total Loss 0.050337
# Iter 0648 | Total Loss 0.050350
# Iter 0649 | Total Loss 0.050363
# Iter 0650 | Total Loss 0.050377
# Iter 0651 | Total Loss 0.050390
# Iter 0652 | Total Loss 0.050403
# Iter 0653 | Total Loss 0.050416
# Iter 0654 | Total Loss 0.050429
# Iter 0655 | Total Loss 0.050443
# Iter 0656 | Total Loss 0.050456
# Iter 0657 | Total Loss 0.050469
# Iter 0658 | Total Loss 0.050482
# Iter 0659 | Total Loss 0.050496
# Iter 0660 | Total Loss 0.050509
# Iter 0661 | Total Loss 0.050522
# Iter 0662 | Total Loss 0.050535
# Iter 0663 | Total Loss 0.050549
# Iter 0664 | Total Loss 0.050562
# Iter 0665 | Total Loss 0.050575
# Iter 0666 | Total Loss 0.050588
# Iter 0667 | Total Loss 0.050602
# Iter 0668 | Total Loss 0.050615
# Iter 0669 | Total Loss 0.050628
# Iter 0670 | Total Loss 0.050642
# Iter 0671 | Total Loss 0.050655
# Iter 0672 | Total Loss 0.050668
# Iter 0673 | Total Loss 0.050682
# Iter 0674 | Total Loss 0.050695
# Iter 0675 | Total Loss 0.050708
# Iter 0676 | Total Loss 0.050721
# Iter 0677 | Total Loss 0.050735
# Iter 0678 | Total Loss 0.050748
# Iter 0679 | Total Loss 0.050761
# Iter 0680 | Total Loss 0.050775
# Iter 0681 | Total Loss 0.050788
# Iter 0682 | Total Loss 0.050801
# Iter 0683 | Total Loss 0.050815
# Iter 0684 | Total Loss 0.050828
# Iter 0685 | Total Loss 0.050841
# Iter 0686 | Total Loss 0.050855
# Iter 0687 | Total Loss 0.050868
# Iter 0688 | Total Loss 0.050881
# Iter 0689 | Total Loss 0.050894
# Iter 0690 | Total Loss 0.050908
# Iter 0691 | Total Loss 0.050921
# Iter 0692 | Total Loss 0.050934
# Iter 0693 | Total Loss 0.050948
# Iter 0694 | Total Loss 0.050961
# Iter 0695 | Total Loss 0.050974
# Iter 0696 | Total Loss 0.050987
# Iter 0697 | Total Loss 0.051001
# Iter 0698 | Total Loss 0.051014
# Iter 0699 | Total Loss 0.051027
# Iter 0700 | Total Loss 0.051040
# Iter 0701 | Total Loss 0.051054
# Iter 0702 | Total Loss 0.051067
# Iter 0703 | Total Loss 0.051080
# Iter 0704 | Total Loss 0.051093
# Iter 0705 | Total Loss 0.051106
# Iter 0706 | Total Loss 0.051120
# Iter 0707 | Total Loss 0.051133
# Iter 0708 | Total Loss 0.051146
# Iter 0709 | Total Loss 0.051159
# Iter 0710 | Total Loss 0.051172
# Iter 0711 | Total Loss 0.051185
# Iter 0712 | Total Loss 0.051199
# Iter 0713 | Total Loss 0.051212
# Iter 0714 | Total Loss 0.051225
# Iter 0715 | Total Loss 0.051238
# Iter 0716 | Total Loss 0.051251
# Iter 0717 | Total Loss 0.051264
# Iter 0718 | Total Loss 0.051277
# Iter 0719 | Total Loss 0.051290
# Iter 0720 | Total Loss 0.051303
# Iter 0721 | Total Loss 0.051316
# Iter 0722 | Total Loss 0.051329
# Iter 0723 | Total Loss 0.051342
# Iter 0724 | Total Loss 0.051355
# Iter 0725 | Total Loss 0.051368
# Iter 0726 | Total Loss 0.051381
# Iter 0727 | Total Loss 0.051394
# Iter 0728 | Total Loss 0.051407
# Iter 0729 | Total Loss 0.051420
# Iter 0730 | Total Loss 0.051433
# Iter 0731 | Total Loss 0.051446
# Iter 0732 | Total Loss 0.051459
# Iter 0733 | Total Loss 0.051472
# Iter 0734 | Total Loss 0.051485
# Iter 0735 | Total Loss 0.051497
# Iter 0736 | Total Loss 0.051510
# Iter 0737 | Total Loss 0.051523
# Iter 0738 | Total Loss 0.051536
# Iter 0739 | Total Loss 0.051549
# Iter 0740 | Total Loss 0.051561
# Iter 0741 | Total Loss 0.051574
# Iter 0742 | Total Loss 0.051587
# Iter 0743 | Total Loss 0.051600
# Iter 0744 | Total Loss 0.051612
# Iter 0745 | Total Loss 0.051625
# Iter 0746 | Total Loss 0.051638
# Iter 0747 | Total Loss 0.051650
# Iter 0748 | Total Loss 0.051663
# Iter 0749 | Total Loss 0.051675
# Iter 0750 | Total Loss 0.051688
# Iter 0751 | Total Loss 0.051701
# Iter 0752 | Total Loss 0.051713
# Iter 0753 | Total Loss 0.051726
# Iter 0754 | Total Loss 0.051738
# Iter 0755 | Total Loss 0.051751
# Iter 0756 | Total Loss 0.051763
# Iter 0757 | Total Loss 0.051776
# Iter 0758 | Total Loss 0.051788
# Iter 0759 | Total Loss 0.051800
# Iter 0760 | Total Loss 0.051813
# Iter 0761 | Total Loss 0.051825
# Iter 0762 | Total Loss 0.051837
# Iter 0763 | Total Loss 0.051850
# Iter 0764 | Total Loss 0.051862
# Iter 0765 | Total Loss 0.051874
# Iter 0766 | Total Loss 0.051887
# Iter 0767 | Total Loss 0.051899
# Iter 0768 | Total Loss 0.051911
# Iter 0769 | Total Loss 0.051923
# Iter 0770 | Total Loss 0.051935
# Iter 0771 | Total Loss 0.051947
# Iter 0772 | Total Loss 0.051960
# Iter 0773 | Total Loss 0.051972
# Iter 0774 | Total Loss 0.051984
# Iter 0775 | Total Loss 0.051996
# Iter 0776 | Total Loss 0.052008
# Iter 0777 | Total Loss 0.052020
# Iter 0778 | Total Loss 0.052032
# Iter 0779 | Total Loss 0.052044
# Iter 0780 | Total Loss 0.052056
# Iter 0781 | Total Loss 0.052067
# Iter 0782 | Total Loss 0.052079
# Iter 0783 | Total Loss 0.052091
# Iter 0784 | Total Loss 0.052103
# Iter 0785 | Total Loss 0.052115
# Iter 0786 | Total Loss 0.052126
# Iter 0787 | Total Loss 0.052138
# Iter 0788 | Total Loss 0.052150
# Iter 0789 | Total Loss 0.052162
# Iter 0790 | Total Loss 0.052173
# Iter 0791 | Total Loss 0.052185
# Iter 0792 | Total Loss 0.052196
# Iter 0793 | Total Loss 0.052208
# Iter 0794 | Total Loss 0.052220
# Iter 0795 | Total Loss 0.052231
# Iter 0796 | Total Loss 0.052243
# Iter 0797 | Total Loss 0.052254
# Iter 0798 | Total Loss 0.052265
# Iter 0799 | Total Loss 0.052277
# Iter 0800 | Total Loss 0.052288
# Iter 0801 | Total Loss 0.052299
# Iter 0802 | Total Loss 0.052311
# Iter 0803 | Total Loss 0.052322
# Iter 0804 | Total Loss 0.052333
# Iter 0805 | Total Loss 0.052345
# Iter 0806 | Total Loss 0.052356
# Iter 0807 | Total Loss 0.052367
# Iter 0808 | Total Loss 0.052378
# Iter 0809 | Total Loss 0.052389
# Iter 0810 | Total Loss 0.052400
# Iter 0811 | Total Loss 0.052411
# Iter 0812 | Total Loss 0.052422
# Iter 0813 | Total Loss 0.052433
# Iter 0814 | Total Loss 0.052444
# Iter 0815 | Total Loss 0.052455
# Iter 0816 | Total Loss 0.052466
# Iter 0817 | Total Loss 0.052477
# Iter 0818 | Total Loss 0.052488
# Iter 0819 | Total Loss 0.052498
# Iter 0820 | Total Loss 0.052509
# Iter 0821 | Total Loss 0.052520
# Iter 0822 | Total Loss 0.052530
# Iter 0823 | Total Loss 0.052541
# Iter 0824 | Total Loss 0.052552
# Iter 0825 | Total Loss 0.052562
# Iter 0826 | Total Loss 0.052573
# Iter 0827 | Total Loss 0.052583
# Iter 0828 | Total Loss 0.052594
# Iter 0829 | Total Loss 0.052604
# Iter 0830 | Total Loss 0.052615
# Iter 0831 | Total Loss 0.052625
# Iter 0832 | Total Loss 0.052635
# Iter 0833 | Total Loss 0.052646
# Iter 0834 | Total Loss 0.052656
# Iter 0835 | Total Loss 0.052666
# Iter 0836 | Total Loss 0.052676
# Iter 0837 | Total Loss 0.052687
# Iter 0838 | Total Loss 0.052697
# Iter 0839 | Total Loss 0.052707
# Iter 0840 | Total Loss 0.052717
# Iter 0841 | Total Loss 0.052727
# Iter 0842 | Total Loss 0.052737
# Iter 0843 | Total Loss 0.052747
# Iter 0844 | Total Loss 0.052757
# Iter 0845 | Total Loss 0.052767
# Iter 0846 | Total Loss 0.052777
# Iter 0847 | Total Loss 0.052786
# Iter 0848 | Total Loss 0.052796
# Iter 0849 | Total Loss 0.052806
# Iter 0850 | Total Loss 0.052816
# Iter 0851 | Total Loss 0.052825
# Iter 0852 | Total Loss 0.052835
# Iter 0853 | Total Loss 0.052844
# Iter 0854 | Total Loss 0.052854
# Iter 0855 | Total Loss 0.052863
# Iter 0856 | Total Loss 0.052873
# Iter 0857 | Total Loss 0.052882
# Iter 0858 | Total Loss 0.052892
# Iter 0859 | Total Loss 0.052901
# Iter 0860 | Total Loss 0.052910
# Iter 0861 | Total Loss 0.052920
# Iter 0862 | Total Loss 0.052929
# Iter 0863 | Total Loss 0.052938
# Iter 0864 | Total Loss 0.052947
# Iter 0865 | Total Loss 0.052956
# Iter 0866 | Total Loss 0.052965
# Iter 0867 | Total Loss 0.052974
# Iter 0868 | Total Loss 0.052983
# Iter 0869 | Total Loss 0.052992
# Iter 0870 | Total Loss 0.053001
# Iter 0871 | Total Loss 0.053010
# Iter 0872 | Total Loss 0.053019
# Iter 0873 | Total Loss 0.053028
# Iter 0874 | Total Loss 0.053037
# Iter 0875 | Total Loss 0.053045
# Iter 0876 | Total Loss 0.053054
# Iter 0877 | Total Loss 0.053063
# Iter 0878 | Total Loss 0.053071
# Iter 0879 | Total Loss 0.053080
# Iter 0880 | Total Loss 0.053088
# Iter 0881 | Total Loss 0.053097
# Iter 0882 | Total Loss 0.053105
# Iter 0883 | Total Loss 0.053113
# Iter 0884 | Total Loss 0.053122
# Iter 0885 | Total Loss 0.053130
# Iter 0886 | Total Loss 0.053138
# Iter 0887 | Total Loss 0.053146
# Iter 0888 | Total Loss 0.053155
# Iter 0889 | Total Loss 0.053163
# Iter 0890 | Total Loss 0.053171
# Iter 0891 | Total Loss 0.053179
# Iter 0892 | Total Loss 0.053187
# Iter 0893 | Total Loss 0.053195
# Iter 0894 | Total Loss 0.053203
# Iter 0895 | Total Loss 0.053210
# Iter 0896 | Total Loss 0.053218
# Iter 0897 | Total Loss 0.053226
# Iter 0898 | Total Loss 0.053234
# Iter 0899 | Total Loss 0.053241
# Iter 0900 | Total Loss 0.053249
# Iter 0901 | Total Loss 0.053257
# Iter 0902 | Total Loss 0.053264
# Iter 0903 | Total Loss 0.053272
# Iter 0904 | Total Loss 0.053279
# Iter 0905 | Total Loss 0.053286
# Iter 0906 | Total Loss 0.053294
# Iter 0907 | Total Loss 0.053301
# Iter 0908 | Total Loss 0.053308
# Iter 0909 | Total Loss 0.053316
# Iter 0910 | Total Loss 0.053323
# Iter 0911 | Total Loss 0.053330
# Iter 0912 | Total Loss 0.053337
# Iter 0913 | Total Loss 0.053344
# Iter 0914 | Total Loss 0.053351
# Iter 0915 | Total Loss 0.053358
# Iter 0916 | Total Loss 0.053365
# Iter 0917 | Total Loss 0.053372
# Iter 0918 | Total Loss 0.053378
# Iter 0919 | Total Loss 0.053385
# Iter 0920 | Total Loss 0.053392
# Iter 0921 | Total Loss 0.053398
# Iter 0922 | Total Loss 0.053405
# Iter 0923 | Total Loss 0.053412
# Iter 0924 | Total Loss 0.053418
# Iter 0925 | Total Loss 0.053425
# Iter 0926 | Total Loss 0.053431
# Iter 0927 | Total Loss 0.053437
# Iter 0928 | Total Loss 0.053444
# Iter 0929 | Total Loss 0.053450
# Iter 0930 | Total Loss 0.053456
# Iter 0931 | Total Loss 0.053462
# Iter 0932 | Total Loss 0.053468
# Iter 0933 | Total Loss 0.053474
# Iter 0934 | Total Loss 0.053480
# Iter 0935 | Total Loss 0.053486
# Iter 0936 | Total Loss 0.053492
# Iter 0937 | Total Loss 0.053498
# Iter 0938 | Total Loss 0.053504
# Iter 0939 | Total Loss 0.053510
# Iter 0940 | Total Loss 0.053515
# Iter 0941 | Total Loss 0.053521
# Iter 0942 | Total Loss 0.053527
# Iter 0943 | Total Loss 0.053532
# Iter 0944 | Total Loss 0.053538
# Iter 0945 | Total Loss 0.053543
# Iter 0946 | Total Loss 0.053549
# Iter 0947 | Total Loss 0.053554
# Iter 0948 | Total Loss 0.053559
# Iter 0949 | Total Loss 0.053565
# Iter 0950 | Total Loss 0.053570
# Iter 0951 | Total Loss 0.053575
# Iter 0952 | Total Loss 0.053580
# Iter 0953 | Total Loss 0.053585
# Iter 0954 | Total Loss 0.053590
# Iter 0955 | Total Loss 0.053595
# Iter 0956 | Total Loss 0.053600
# Iter 0957 | Total Loss 0.053605
# Iter 0958 | Total Loss 0.053609
# Iter 0959 | Total Loss 0.053614
# Iter 0960 | Total Loss 0.053619
# Iter 0961 | Total Loss 0.053623
# Iter 0962 | Total Loss 0.053628
# Iter 0963 | Total Loss 0.053633
# Iter 0964 | Total Loss 0.053637
# Iter 0965 | Total Loss 0.053641
# Iter 0966 | Total Loss 0.053646
# Iter 0967 | Total Loss 0.053650
# Iter 0968 | Total Loss 0.053654
# Iter 0969 | Total Loss 0.053658
# Iter 0970 | Total Loss 0.053663
# Iter 0971 | Total Loss 0.053667
# Iter 0972 | Total Loss 0.053671
# Iter 0973 | Total Loss 0.053675
# Iter 0974 | Total Loss 0.053679
# Iter 0975 | Total Loss 0.053682
# Iter 0976 | Total Loss 0.053686
# Iter 0977 | Total Loss 0.053690
# Iter 0978 | Total Loss 0.053694
# Iter 0979 | Total Loss 0.053697
# Iter 0980 | Total Loss 0.053701
# Iter 0981 | Total Loss 0.053704
# Iter 0982 | Total Loss 0.053708
# Iter 0983 | Total Loss 0.053711
# Iter 0984 | Total Loss 0.053715
# Iter 0985 | Total Loss 0.053718
# Iter 0986 | Total Loss 0.053721
# Iter 0987 | Total Loss 0.053724
# Iter 0988 | Total Loss 0.053728
# Iter 0989 | Total Loss 0.053731
# Iter 0990 | Total Loss 0.053734
# Iter 0991 | Total Loss 0.053737
# Iter 0992 | Total Loss 0.053740
# Iter 0993 | Total Loss 0.053742
# Iter 0994 | Total Loss 0.053745
# Iter 0995 | Total Loss 0.053748
# Iter 0996 | Total Loss 0.053751
# Iter 0997 | Total Loss 0.053753
# Iter 0998 | Total Loss 0.053756
# Iter 0999 | Total Loss 0.053758

# %% [markdown]
# ### Visualize

# %%
# plotting
xode = odeint(npode, x0, t).detach().numpy()
U = npode.U.detach().numpy()
Z = npode.Z.detach().numpy()
xode = np.transpose(xode,[1,0,2])

cols = ['r','b','g','m','c','k']
plt.figure(1,[7,10])
plt.scatter(Z[:,0],Z[:,1],100, facecolors='none', edgecolors='k')
plt.quiver(Z[:,0],Z[:,1],U[:,0],U[:,1],units='height',width=0.006,color='k')
for i in range(min(6,xode.shape[0])):
    plt.plot(X[i,:,0],X[i,:,1],'o',color=cols[i])
    plt.plot(xode[i,:,0],xode[i,:,1],'-',color=cols[i])

# %% [markdown]
# ## Old stuff

# %%
# working
M   = 6 # MxM inducing grid
D   = 2
sf  = 1
ell = 0.75

torch.set_default_tensor_type(torch.DoubleTensor)
xv = np.linspace(np.min([np.min(Y_[:,0]) for Y_ in Y]), np.max([np.max(Y_[:,0]) for Y_ in Y]), M)
yv = np.linspace(np.min([np.min(Y_[:,1]) for Y_ in Y]), np.max([np.max(Y_[:,1]) for Y_ in Y]), M)
xv,yv = np.meshgrid(xv,yv)
Z  = np.array([xv.T.flatten(),yv.T.flatten()]).T
Zt = torch.from_numpy(Z)
Yt = torch.from_numpy(Y)
U0 = 0.1*torch.randn(M*M, D)
# U0 = VDP().forward(0,Zt)

def _flatten(sequence):
    flat = [p.contiguous().view(-1) for p in sequence]
    return torch.cat(flat) if len(flat) > 0 else torch.tensor([])

def sq_dist(X1,X2):
    X1 = X1 / ell
    X1s = torch.sum(X1**2, dim=1).view([-1,1]) 
    X2 = X2 / ell
    X2s = torch.sum(X2**2, dim=1).view([1,-1])
    return -2*torch.mm(X1,torch.t(X2)) + X1s + X2s

def K(X1,X2):
    dist = sq_dist(X1,X2)
    return sf**2 * torch.exp(-dist / 2)

# gradient matching
# F_ = (Yt[:,1:,:]-Yt[:,:-1,:]) / (t[1]-t[0])
# F_ = F_.contiguous().view(-1,D)
# Z_ = Yt[:,:-1,:].contiguous().view(-1,D)
# Kxz = K(Zt,Z_)
# Kzzinv = (K(Z_,Z_)+0.2*torch.eye(Z_.shape[0])).inverse()
# U0 = torch.mm(torch.mm(Kxz,Kzzinv),F_) # not whitened
# Linv = torch.cholesky(K(Zt,Zt)).inverse()
# U0 = torch.mm(Linv,U0) # whitened

class KernelRegression(torch.nn.Module):
    def __init__(self):
        super(KernelRegression, self).__init__()
        self.U = torch.nn.Parameter(U0, requires_grad=True)
        self.Z = Zt
        self.Kzz = K(Zt,Zt)
        self.Kzzinv = self.Kzz.inverse()
        self.L = torch.cholesky(self.Kzz)
        self.KzzinvL = torch.mm(self.Kzzinv,self.L)

    def forward(self, t, X):
        T = torch.mm(K(X,self.Z),self.KzzinvL)
        return torch.mm(T,self.U)

class ODEINT_FS(torch.autograd.Function):
    @staticmethod
    def forward(ctx, func, x0, t, th):
        xode = odeint(func, x0, t, method='rk4').permute([1,0,2])
        ctx.func = func
        ctx.save_for_backward(x0,t,th,xode)
        return xode # N,T,D
    @staticmethod
    def backward(ctx, *grad_output): # grad_output[0] N,T,D ---> dL/dxode
        # print('backward')
        func = ctx.func
        x0,t,th,xode = ctx.saved_tensors
        D = x0.shape[1]  # problem dimensionality
        MD = torch.numel(th) # number of parameters in the differential function
        with torch.no_grad():
            def ode_sens_rhs(t,xS):
                x = xS[0:D].view(-1,D).detach().requires_grad_(True)
                S = xS[D:].view(D,MD)
                th = list(func.parameters())[0]
                J = [] # accumulate columns of J here
                R = [] # accumulate columns of R here
                for i in range(D): # partial derivative of output dimension i 
                    with torch.set_grad_enabled(True):
                        f = func(t,x)[0,i]
                        dfdxth = torch.autograd.grad(f, [x,th], allow_unused=False, retain_graph=False)
                        J.append(dfdxth[0])
                        R.append(dfdxth[1])
                J = torch.cat(J)  # D,D
                R = torch.cat([r.view(1,-1) for r in R]) # D,MD
                dS = torch.matmul(J,S)+R
                dx = func(t,x)[0]
                dxdS = torch.cat((dx.view(-1),dS.view(-1)))
                return dxdS
            S0 = torch.zeros(D,MD)
            xS0 = torch.cat((x0.view(-1),S0.view(-1)),0)
            xS = odeint(ode_sens_rhs, xS0, t, method='rk4') # T,1,(D+DMD)
            xode2 = xS[:,0:2].unsqueeze(0) # 1,T,D
            # print('error between two ode integrations is {:f}'.format(torch.abs(xode-xode2).sum().numpy()))
            S = xS[:,2:].t().view(D,MD,-1).permute([0,2,1]) # D,T,MD
            dlossdx = grad_output[0][0].t().unsqueeze(2) # D,T,1
            dlossdU = torch.sum(S*dlossdx,[0,1]) # MD
        return None,None,None,dlossdU # N,T,D
    
odeint_fs = ODEINT_FS.apply
kreg = KernelRegression()

# check why doesn't work
# from torch.autograd import gradcheck
# th_ = _flatten(kreg.parameters())
# test = gradcheck(odeint_fs, [kreg,x0,t,th_], eps=1e-6, atol=1e-4)
# print(test)

def odeint_forw_sens(func, x0, t):
    th = _flatten(func.parameters())
    xode = odeint_fs(kreg, x0, t, th)
    return xode
    
logsn = torch.nn.Parameter(torch.zeros(2), requires_grad=True)
params = [kreg.U,logsn]
optimizer = optim.Adam(params, lr=5e-3)
    
for itr in range(500):
    optimizer.zero_grad()
    xode = odeint_forw_sens(kreg,x0,t)
    loss = torch.sum((Yt-xode)**2 / torch.exp(logsn)**2) +  torch.numel(Yt)*torch.sum(logsn)/D
    loss.backward()
    optimizer.step()

    if itr % 1 == 0:
        with torch.no_grad():
            xode = odeint_forw_sens(kreg,x0,t)
            loss = torch.sum((Yt-xode)**2 / torch.exp(logsn)**2) +  torch.numel(Yt)*torch.sum(logsn)/D
            print('Iter {:04d} | Total Loss {:.6f}'.format(itr, loss.item()))

    # break
    end = time.time()

# %% [markdown]
# ## Inference using MCMC

# %% [markdown]
# ### Initialize Model and params

# %%
# # create variables, functions etc
# M   = 6 # MxM inducing grid
# D   = 2
# sf  = 1
# ell = 0.75

# torch.set_default_tensor_type(torch.DoubleTensor)
# xv = np.linspace(np.min([np.min(Y_[:,0]) for Y_ in Y]), np.max([np.max(Y_[:,0]) for Y_ in Y]), M)
# yv = np.linspace(np.min([np.min(Y_[:,1]) for Y_ in Y]), np.max([np.max(Y_[:,1]) for Y_ in Y]), M)
# xv,yv = np.meshgrid(xv,yv)
# Z  = np.array([xv.T.flatten(),yv.T.flatten()]).T
# Zt = torch.from_numpy(Z)
# Yt = torch.from_numpy(Y)
# U0 = 0.1*torch.randn(M*M, D)
# # U0 = VDP().forward(0,Zt)

# def _flatten(sequence):
#     flat = [p.contiguous().view(-1) for p in sequence]
#     return torch.cat(flat) if len(flat) > 0 else torch.tensor([])

# def sq_dist(X1,X2):
#     X1 = X1 / ell
#     X1s = torch.sum(X1**2, dim=1).view([-1,1]) 
#     X2 = X2 / ell
#     X2s = torch.sum(X2**2, dim=1).view([1,-1])
#     return -2*torch.mm(X1,torch.t(X2)) + X1s + X2s

# def K(X1,X2):
#     dist = sq_dist(X1,X2)
#     return sf**2 * torch.exp(-dist / 2)

# # gradient matching
# F_ = (Yt[:,1:,:]-Yt[:,:-1,:]) / (t[1]-t[0])
# F_ = F_.contiguous().view(-1,D)
# Z_ = Yt[:,:-1,:].contiguous().view(-1,D)
# Kxz = K(Zt,Z_)
# Kzzinv = (K(Z_,Z_)+0.2*torch.eye(Z_.shape[0])).inverse()
# U0 = torch.mm(torch.mm(Kxz,Kzzinv),F_) # not whitened
# Linv = torch.cholesky(K(Zt,Zt)).inverse()
# U0 = torch.mm(Linv,U0) # whitened

# class KernelRegression(torch.nn.Module):
#     def __init__(self):
#         super(KernelRegression, self).__init__()
#         self.U = torch.nn.Parameter(U0, requires_grad=True)
#         self.Z = Zt
#         self.Kzz = K(Zt,Zt)
#         self.Kzzinv = self.Kzz.inverse()
#         self.L = torch.cholesky(self.Kzz)
#         self.KzzinvL = torch.mm(self.Kzzinv,self.L)

#     def forward(self, t, X):
#         T = torch.mm(K(X,self.Z),self.KzzinvL)
#         return torch.mm(T,self.U)

# class ODEINT_FS(torch.autograd.Function):
#     @staticmethod
#     def forward(ctx, func, x0, t, th):
#         xode = odeint(func, x0, t, method='rk4').permute([1,0,2])
#         ctx.func = func
#         ctx.save_for_backward(x0,t,th,xode)
#         return xode # N,T,D
#     @staticmethod
#     def backward(ctx, *grad_output): # grad_output[0] N,T,D ---> dL/dxode
#         # print('backward')
#         func = ctx.func
#         x0,t,th,xode = ctx.saved_tensors
#         N = x0.shape[0]  # problem dimensionality
#         D = x0.shape[1]  # problem dimensionality
#         MD = torch.numel(th) # number of parameters in the differential function
#         with torch.no_grad():
#             def ode_sens_rhs(t,xS): # xS = N,D,(1+MD)
#                 x = xS[:,:,0].view(-1,D) # N,D
#                 S = xS[:,:,1:] # N,D,MD
#                 th = list(func.parameters())[0]
#                 dxs = []
#                 dSs = []
#                 for j in range(N):
#                     x_ = x[j:j+1].requires_grad_(True) #.detach() # 1,D
#                     S_ = S[j] # D,MD
#                     J = [] # accumulate columns of J here
#                     R = [] # accumulate columns of R here
#                     for i in range(D): # partial derivative of output dimension i 
#                         with torch.set_grad_enabled(True):
#                             f = func(t,x_)[0,i]
#                             dfdxth = torch.autograd.grad(f, [x_,th], allow_unused=False, retain_graph=False)
#                             J.append(dfdxth[0])
#                             R.append(dfdxth[1].view(1,-1)) # 1,MD
#                     J = torch.cat(J) # D,D
#                     R = torch.cat(R) # D,MD
#                     dS = torch.matmul(J,S_)+R # D,MD
#                     dx = func(t,x_) # 1,D
#                     dxs.append(dx.unsqueeze(2)) # 1,D,1
#                     dSs.append(dS.unsqueeze(0)) # 1,D,MD
#                 dx = torch.cat(dxs) # N,D,1
#                 dS = torch.cat(dSs) # N,D,MD
#                 dxdS = torch.cat([dx,dS],2)
#                 return dxdS
#             x0 = torch.unsqueeze(x0,2) # N,D,1
#             S0 = torch.zeros(N,D,MD)
#             xS0 = torch.cat((x0,S0),2) # N,D,(1+MD)
#             xS = odeint(ode_sens_rhs, xS0, t, method='rk4') # T,N,D,(1+MD)
#             xode2 = xS[:,:,:,0].permute([1,0,2]) # N,T,D
#             # print('error between two ode integrations is {:f}'.format(torch.abs(xode-xode2).sum().numpy()))
#             S = xS[:,:,:,1:].permute([1,2,0,3]) # N,D,T,MD
#             # print(grad_output[0].shape) # N,T,D
#             dlossdx = grad_output[0].permute([0,2,1]).unsqueeze(3) # N,D,T,1
#             dlossdU = torch.sum(S*dlossdx,[0,1,2]) # MD
#         return None,None,None,dlossdU # N,T,D
    
# odeint_fs = ODEINT_FS.apply
# kreg = KernelRegression()

# # check why doesn't work
# # from torch.autograd import gradcheck
# # th_ = _flatten(kreg.parameters())
# # test = gradcheck(odeint_fs, [kreg,x0,t,th_], eps=1e-6, atol=1e-4)
# # print(test)

# def odeint_forw_sens(func, x0, t):
#     th = _flatten(func.parameters())
#     xode = odeint_fs(kreg, x0, t, th)
#     return xode
    
# create variables, functions etc
M   = 6 # MxM inducing grid
D   = 2
sf  = 1
ell = 0.75

torch.set_default_tensor_type(torch.DoubleTensor)
xv = np.linspace(np.min([np.min(Y_[:,0]) for Y_ in Y]), np.max([np.max(Y_[:,0]) for Y_ in Y]), M)
yv = np.linspace(np.min([np.min(Y_[:,1]) for Y_ in Y]), np.max([np.max(Y_[:,1]) for Y_ in Y]), M)
xv,yv = np.meshgrid(xv,yv)
Z  = np.array([xv.T.flatten(),yv.T.flatten()]).T
Zt = torch.from_numpy(Z)
Xt = torch.from_numpy(X)
U0 = 0.1*torch.randn(M*M, D)
# U0 = VDP().forward(0,Zt)

def sq_dist(X1,X2):
    X1 = X1 / ell
    X1s = torch.sum(X1**2, dim=1).view([-1,1]) 
    X2 = X2 / ell
    X2s = torch.sum(X2**2, dim=1).view([1,-1])
    return -2*torch.mm(X1,torch.t(X2)) + X1s + X2s

def K(X1,X2):
    dist = sq_dist(X1,X2)
    return sf**2 * torch.exp(-dist / 2)

# # gradient matching
F_ = (Xt[:,1:,:]-Xt[:,:-1,:]) / (t[1]-t[0])
F_ = F_.contiguous().view(-1,D)
Z_ = Xt[:,:-1,:].contiguous().view(-1,D)
Kxz = K(Zt,Z_)
Kzzinv = (K(Z_,Z_)+0.2*torch.eye(Z_.shape[0])).inverse()
U0 = torch.mm(torch.mm(Kxz,Kzzinv),F_)


class KernelRegression(torch.nn.Module):
    def __init__(self):
        super(KernelRegression, self).__init__()
        self.U = torch.nn.Parameter(U0, requires_grad=True)
        self.logsn = torch.nn.Parameter(torch.zeros(2), requires_grad=True)
        self.Z = Zt

    def forward(self, t, X):
#         Z = self.Z
#         M = Z.shape[0]
#         N = X.shape[0]
#         A_LU = torch.lu(K(Z,Z).view(-1,M,M)) # 1,M,M
#         Kxz  = torch.t(K(X,Z)).view(-1,M,N)  # 1,M,N
#         A = torch.lu_solve(Kxz, *A_LU).view(M,N) # M x N
#         f = torch.mm(torch.t(A),self.U) # N x M
#         return f
#         Z = self.Z
#         Ltinv = torch.t(torch.cholesky(K(Z,Z))).inverse()
#         return torch.mm(torch.mm(K(X,Z),Ltinv),self.U)
        Z = self.Z
        Kzzinv = K(Z,Z).inverse()
        return torch.mm(torch.mm(K(X,Z),Kzzinv),self.U)

kreg = KernelRegression()
Kzzinv = K(Zt, Zt).inverse()
# lbfgs = optim.LBFGS(npode.parameters(), lr=5e-3)
# optimizer = optim.Adam(npode.parameters(), lr=5e-3)

# %% [markdown]
# ### Inference

# %%
from samplers.metrics import *


itr = 0

def closure():
    global itr
    T   = min(3+itr//1, len(t))
    T   = len(t)
    itr += 1
    t_  = t[:T]
    Xt_ = Xt[:,:T,:]
    xode = odeint(kreg, x0, t_, method='rk4').permute([1,0,2])
    loss = torch.sum((Xt_-xode)**2 / torch.exp(kreg.logsn)**2) +  torch.numel(Xt_)*torch.sum(kreg.logsn)/D + \
        torch.sum(torch.diag(torch.mm(kreg.U.t(),torch.mm(Kzzinv, kreg.U))))/2
    return loss

def hess_closure():
    hess = eval_full_hessian(torch.autograd.grad(closure(), params, create_graph=True), params)
#     plt.figure()
#     plt.imshow(hess.clone().detach().numpy())
#     plt.colorbar()
    return hess


logsn = torch.nn.Parameter(torch.zeros(2), requires_grad=True)
# params = kreg.parameters()
params = [kreg.U]
# sampler = MALA(params, lr=0.0001, add_noise=False)


#### Computimng size of full hessian #####
cnt = 0
loss_grad = torch.autograd.grad(closure(), params)
for g in loss_grad:
    g_vector = g.contiguous().view(-1) if cnt == 0\
                else torch.cat([g_vector, g.contiguous().view(-1)])
    cnt = 1
l = g_vector.size(0)
#########################################

# metric = SoftAbsMetric(closure=hess_closure, softabs_coeff=10)
metric = HessianMetric(closure=hess_closure)
# metric = IdentityMetric(size=l)

# %%
from samplers import MALA, SGLD, MMALA

# sampler = MMALA(params, metric_obj=metric, lr=1e-4)
sampler = MALA(params, lr=1e-4, add_noise=True)
# sampler = SGLD(params, lr0=0.0001, gamma=0.55, t0=100, alpha=0.1)


chain, logp_array = sampler.sample(closure, burn_in=2000, num_samples=1000)
# Out:
# <class 'dict'>
# Burn-in phase started
# Burn-in iter 1
# Burn-in iter 2
# Burn-in iter 3
# Burn-in iter 4
# Burn-in iter 5
# Burn-in iter 6
# Burn-in iter 7
# Burn-in iter 8
# Burn-in iter 9
# Burn-in iter 10
# Burn-in iter 11
# Burn-in iter 12
# Burn-in iter 13
# Burn-in iter 14
# Burn-in iter 15
# Burn-in iter 16
# Burn-in iter 17
# Burn-in iter 18
# Burn-in iter 19
# Burn-in iter 20
# Burn-in iter 21
# Burn-in iter 22
# Burn-in iter 23
# Burn-in iter 24
# Burn-in iter 25
# Burn-in iter 26
# Burn-in iter 27
# Burn-in iter 28
# Burn-in iter 29
# Burn-in iter 30
# Burn-in iter 31
# Burn-in iter 32
# Burn-in iter 33
# Burn-in iter 34
# Burn-in iter 35
# Burn-in iter 36
# Burn-in iter 37
# Burn-in iter 38
# Burn-in iter 39
# Burn-in iter 40
# Burn-in iter 41
# Burn-in iter 42
# Burn-in iter 43
# Burn-in iter 44
# Burn-in iter 45
# Burn-in iter 46
# Burn-in iter 47
# Burn-in iter 48
# Burn-in iter 49
# Burn-in iter 50
# Burn-in iter 51
# Burn-in iter 52
# Burn-in iter 53
# Burn-in iter 54
# Burn-in iter 55
# Burn-in iter 56
# Burn-in iter 57
# Burn-in iter 58
# Burn-in iter 59
# Burn-in iter 60
# Burn-in iter 61
# Burn-in iter 62
# Burn-in iter 63
# Burn-in iter 64
# Burn-in iter 65
# Burn-in iter 66
# Burn-in iter 67
# Burn-in iter 68
# Burn-in iter 69
# Burn-in iter 70
# Burn-in iter 71
# Burn-in iter 72
# Burn-in iter 73
# Burn-in iter 74
# Burn-in iter 75
# Burn-in iter 76
# Burn-in iter 77
# Burn-in iter 78
# Burn-in iter 79
# Burn-in iter 80
# Burn-in iter 81
# Burn-in iter 82
# Burn-in iter 83
# Burn-in iter 84
# Burn-in iter 85
# Burn-in iter 86
# Burn-in iter 87
# Burn-in iter 88
# Burn-in iter 89
# Burn-in iter 90
# Burn-in iter 91
# Burn-in iter 92
# Burn-in iter 93
# Burn-in iter 94
# Burn-in iter 95
# Burn-in iter 96
# Burn-in iter 97
# Burn-in iter 98
# Burn-in iter 99
# Burn-in iter 100
# Burn-in iter 101
# Burn-in iter 102
# Burn-in iter 103
# Burn-in iter 104
# Burn-in iter 105
# Burn-in iter 106
# Burn-in iter 107
# Burn-in iter 108
# Burn-in iter 109
# Burn-in iter 110
# Burn-in iter 111
# Burn-in iter 112
# Burn-in iter 113
# Burn-in iter 114
# Burn-in iter 115
# Burn-in iter 116
# Burn-in iter 117
# Burn-in iter 118
# Burn-in iter 119
# Burn-in iter 120
# Burn-in iter 121
# Burn-in iter 122
# Burn-in iter 123
# Burn-in iter 124
# Burn-in iter 125
# Burn-in iter 126
# Burn-in iter 127
# Burn-in iter 128
# Burn-in iter 129
# Burn-in iter 130
# Burn-in iter 131
# Burn-in iter 132
# Burn-in iter 133
# Burn-in iter 134
# Burn-in iter 135
# Burn-in iter 136
# Burn-in iter 137
# Burn-in iter 138
# Burn-in iter 139
# Burn-in iter 140
# Burn-in iter 141
# Burn-in iter 142
# Burn-in iter 143
# Burn-in iter 144
# Burn-in iter 145
# Burn-in iter 146
# Burn-in iter 147
# Burn-in iter 148
# Burn-in iter 149
# Burn-in iter 150
# Burn-in iter 151
# Burn-in iter 152
# Burn-in iter 153
# Burn-in iter 154
# Burn-in iter 155
# Burn-in iter 156
# Burn-in iter 157
# Burn-in iter 158
# Burn-in iter 159
# Burn-in iter 160
# Burn-in iter 161
# Burn-in iter 162
# Burn-in iter 163
# Burn-in iter 164
# Burn-in iter 165
# Burn-in iter 166
# Burn-in iter 167
# Burn-in iter 168
# Burn-in iter 169
# Burn-in iter 170
# Burn-in iter 171
# Burn-in iter 172
# Burn-in iter 173
# Burn-in iter 174
# Burn-in iter 175
# Burn-in iter 176
# Burn-in iter 177
# Burn-in iter 178
# Burn-in iter 179
# Burn-in iter 180
# Burn-in iter 181
# Burn-in iter 182
# Burn-in iter 183
# Burn-in iter 184
# Burn-in iter 185
# Burn-in iter 186
# Burn-in iter 187
# Burn-in iter 188
# Burn-in iter 189
# Burn-in iter 190
# Burn-in iter 191
# Burn-in iter 192
# Burn-in iter 193
# Burn-in iter 194
# Burn-in iter 195
# Burn-in iter 196
# Burn-in iter 197
# Burn-in iter 198
# Burn-in iter 199
# Burn-in iter 200
# Burn-in iter 201
# Burn-in iter 202
# Burn-in iter 203
# Burn-in iter 204
# Burn-in iter 205
# Burn-in iter 206
# Burn-in iter 207
# Burn-in iter 208
# Burn-in iter 209
# Burn-in iter 210
# Burn-in iter 211
# Burn-in iter 212
# Burn-in iter 213
# Burn-in iter 214
# Burn-in iter 215
# Burn-in iter 216
# Burn-in iter 217
# Burn-in iter 218
# Burn-in iter 219
# Burn-in iter 220
# Burn-in iter 221
# Burn-in iter 222
# Burn-in iter 223
# Burn-in iter 224
# Burn-in iter 225
# Burn-in iter 226
# Burn-in iter 227
# Burn-in iter 228
# Burn-in iter 229
# Burn-in iter 230
# Burn-in iter 231
# Burn-in iter 232
# Burn-in iter 233
# Burn-in iter 234
# Burn-in iter 235
# Burn-in iter 236
# Burn-in iter 237
# Burn-in iter 238
# Burn-in iter 239
# Burn-in iter 240
# Burn-in iter 241
# Burn-in iter 242
# Burn-in iter 243
# Burn-in iter 244
# Burn-in iter 245
# Burn-in iter 246
# Burn-in iter 247
# Burn-in iter 248
# Burn-in iter 249
# Burn-in iter 250
# Burn-in iter 251
# Burn-in iter 252
# Burn-in iter 253
# Burn-in iter 254
# Burn-in iter 255
# Burn-in iter 256
# Burn-in iter 257
# Burn-in iter 258
# Burn-in iter 259
# Burn-in iter 260
# Burn-in iter 261
# Burn-in iter 262
# Burn-in iter 263
# Burn-in iter 264
# Burn-in iter 265
# Burn-in iter 266
# Burn-in iter 267
# Burn-in iter 268
# Burn-in iter 269
# Burn-in iter 270
# Burn-in iter 271
# Burn-in iter 272
# Burn-in iter 273
# Burn-in iter 274
# Burn-in iter 275
# Burn-in iter 276
# Burn-in iter 277
# Burn-in iter 278
# Burn-in iter 279
# Burn-in iter 280
# Burn-in iter 281
# Burn-in iter 282
# Burn-in iter 283
# Burn-in iter 284
# Burn-in iter 285
# Burn-in iter 286
# Burn-in iter 287
# Burn-in iter 288
# Burn-in iter 289
# Burn-in iter 290
# Burn-in iter 291
# Burn-in iter 292
# Burn-in iter 293
# Burn-in iter 294
# Burn-in iter 295
# Burn-in iter 296
# Burn-in iter 297
# Burn-in iter 298
# Burn-in iter 299
# Burn-in iter 300
# Burn-in iter 301
# Burn-in iter 302
# Burn-in iter 303
# Burn-in iter 304
# Burn-in iter 305
# Burn-in iter 306
# Burn-in iter 307
# Burn-in iter 308
# Burn-in iter 309
# Burn-in iter 310
# Burn-in iter 311
# Burn-in iter 312
# Burn-in iter 313
# Burn-in iter 314
# Burn-in iter 315
# Burn-in iter 316
# Burn-in iter 317
# Burn-in iter 318
# Burn-in iter 319
# Burn-in iter 320
# Burn-in iter 321
# Burn-in iter 322
# Burn-in iter 323
# Burn-in iter 324
# Burn-in iter 325
# Burn-in iter 326
# Burn-in iter 327
# Burn-in iter 328
# Burn-in iter 329
# Burn-in iter 330
# Burn-in iter 331
# Burn-in iter 332
# Burn-in iter 333
# Burn-in iter 334
# Burn-in iter 335
# Burn-in iter 336
# Burn-in iter 337
# Burn-in iter 338
# Burn-in iter 339
# Burn-in iter 340
# Burn-in iter 341
# Burn-in iter 342
# Burn-in iter 343
# Burn-in iter 344
# Burn-in iter 345
# Burn-in iter 346
# Burn-in iter 347
# Burn-in iter 348
# Burn-in iter 349
# Burn-in iter 350
# Burn-in iter 351
# Burn-in iter 352
# Burn-in iter 353
# Burn-in iter 354
# Burn-in iter 355
# Burn-in iter 356
# Burn-in iter 357
# Burn-in iter 358
# Burn-in iter 359
# Burn-in iter 360
# Burn-in iter 361
# Burn-in iter 362
# Burn-in iter 363
# Burn-in iter 364
# Burn-in iter 365
# Burn-in iter 366
# Burn-in iter 367
# Burn-in iter 368
# Burn-in iter 369
# Burn-in iter 370
# Burn-in iter 371
# Burn-in iter 372
# Burn-in iter 373
# Burn-in iter 374
# Burn-in iter 375
# Burn-in iter 376
# Burn-in iter 377
# Burn-in iter 378
# Burn-in iter 379
# Burn-in iter 380
# Burn-in iter 381
# Burn-in iter 382
# Burn-in iter 383
# Burn-in iter 384
# Burn-in iter 385
# Burn-in iter 386
# Burn-in iter 387
# Burn-in iter 388
# Burn-in iter 389
# Burn-in iter 390
# Burn-in iter 391
# Burn-in iter 392
# Burn-in iter 393
# Burn-in iter 394
# Burn-in iter 395
# Burn-in iter 396
# Burn-in iter 397
# Burn-in iter 398
# Burn-in iter 399
# Burn-in iter 400
# Burn-in iter 401
# Burn-in iter 402
# Burn-in iter 403
# Burn-in iter 404
# Burn-in iter 405
# Burn-in iter 406
# Burn-in iter 407
# Burn-in iter 408
# Burn-in iter 409
# Burn-in iter 410
# Burn-in iter 411
# Burn-in iter 412
# Burn-in iter 413
# Burn-in iter 414
# Burn-in iter 415
# Burn-in iter 416
# Burn-in iter 417
# Burn-in iter 418
# Burn-in iter 419
# Burn-in iter 420
# Burn-in iter 421
# Burn-in iter 422
# Burn-in iter 423
# Burn-in iter 424
# Burn-in iter 425
# Burn-in iter 426
# Burn-in iter 427
# Burn-in iter 428
# Burn-in iter 429
# Burn-in iter 430
# Burn-in iter 431
# Burn-in iter 432
# Burn-in iter 433
# Burn-in iter 434
# Burn-in iter 435
# Burn-in iter 436
# Burn-in iter 437
# Burn-in iter 438
# Burn-in iter 439
# Burn-in iter 440
# Burn-in iter 441
# Burn-in iter 442
# Burn-in iter 443
# Burn-in iter 444
# Burn-in iter 445
# Burn-in iter 446
# Burn-in iter 447
# Burn-in iter 448
# Burn-in iter 449
# Burn-in iter 450
# Burn-in iter 451
# Burn-in iter 452
# Burn-in iter 453
# Burn-in iter 454
# Burn-in iter 455
# Burn-in iter 456
# Burn-in iter 457
# Burn-in iter 458
# Burn-in iter 459
# Burn-in iter 460
# Burn-in iter 461
# Burn-in iter 462
# Burn-in iter 463
# Burn-in iter 464
# Burn-in iter 465
# Burn-in iter 466
# Burn-in iter 467
# Burn-in iter 468
# Burn-in iter 469
# Burn-in iter 470
# Burn-in iter 471
# Burn-in iter 472
# Burn-in iter 473
# Burn-in iter 474
# Burn-in iter 475
# Burn-in iter 476
# Burn-in iter 477
# Burn-in iter 478
# Burn-in iter 479
# Burn-in iter 480
# Burn-in iter 481
# Burn-in iter 482
# Burn-in iter 483
# Burn-in iter 484
# Burn-in iter 485
# Burn-in iter 486
# Burn-in iter 487
# Burn-in iter 488
# Burn-in iter 489
# Burn-in iter 490
# Burn-in iter 491
# Burn-in iter 492
# Burn-in iter 493
# Burn-in iter 494
# Burn-in iter 495
# Burn-in iter 496
# Burn-in iter 497
# Burn-in iter 498
# Burn-in iter 499
# Burn-in iter 500
# Burn-in iter 501
# Burn-in iter 502
# Burn-in iter 503
# Burn-in iter 504
# Burn-in iter 505
# Burn-in iter 506
# Burn-in iter 507
# Burn-in iter 508
# Burn-in iter 509
# Burn-in iter 510
# Burn-in iter 511
# Burn-in iter 512
# Burn-in iter 513
# Burn-in iter 514
# Burn-in iter 515
# Burn-in iter 516
# Burn-in iter 517
# Burn-in iter 518
# Burn-in iter 519
# Burn-in iter 520
# Burn-in iter 521
# Burn-in iter 522
# Burn-in iter 523
# Burn-in iter 524
# Burn-in iter 525
# Burn-in iter 526
# Burn-in iter 527
# Burn-in iter 528
# Burn-in iter 529
# Burn-in iter 530
# Burn-in iter 531
# Burn-in iter 532
# Burn-in iter 533
# Burn-in iter 534
# Burn-in iter 535
# Burn-in iter 536
# Burn-in iter 537
# Burn-in iter 538
# Burn-in iter 539
# Burn-in iter 540
# Burn-in iter 541
# Burn-in iter 542
# Burn-in iter 543
# Burn-in iter 544
# Burn-in iter 545
# Burn-in iter 546
# Burn-in iter 547
# Burn-in iter 548
# Burn-in iter 549
# Burn-in iter 550
# Burn-in iter 551
# Burn-in iter 552
# Burn-in iter 553
# Burn-in iter 554
# Burn-in iter 555
# Burn-in iter 556
# Burn-in iter 557
# Burn-in iter 558
# Burn-in iter 559
# Burn-in iter 560
# Burn-in iter 561
# Burn-in iter 562
# Burn-in iter 563
# Burn-in iter 564
# Burn-in iter 565
# Burn-in iter 566
# Burn-in iter 567
# Burn-in iter 568
# Burn-in iter 569
# Burn-in iter 570
# Burn-in iter 571
# Burn-in iter 572
# Burn-in iter 573
# Burn-in iter 574
# Burn-in iter 575
# Burn-in iter 576
# Burn-in iter 577
# Burn-in iter 578
# Burn-in iter 579
# Burn-in iter 580
# Burn-in iter 581
# Burn-in iter 582
# Burn-in iter 583
# Burn-in iter 584
# Burn-in iter 585
# Burn-in iter 586
# Burn-in iter 587
# Burn-in iter 588
# Burn-in iter 589
# Burn-in iter 590
# Burn-in iter 591
# Burn-in iter 592
# Burn-in iter 593
# Burn-in iter 594
# Burn-in iter 595
# Burn-in iter 596
# Burn-in iter 597
# Burn-in iter 598
# Burn-in iter 599
# Burn-in iter 600
# Burn-in iter 601
# Burn-in iter 602
# Burn-in iter 603
# Burn-in iter 604
# Burn-in iter 605
# Burn-in iter 606
# Burn-in iter 607
# Burn-in iter 608
# Burn-in iter 609
# Burn-in iter 610
# Burn-in iter 611
# Burn-in iter 612
# Burn-in iter 613
# Burn-in iter 614
# Burn-in iter 615
# Burn-in iter 616
# Burn-in iter 617
# Burn-in iter 618
# Burn-in iter 619
# Burn-in iter 620
# Burn-in iter 621
# Burn-in iter 622
# Burn-in iter 623
# Burn-in iter 624
# Burn-in iter 625
# Burn-in iter 626
# Burn-in iter 627
# Burn-in iter 628
# Burn-in iter 629
# Burn-in iter 630
# Burn-in iter 631
# Burn-in iter 632
# Burn-in iter 633
# Burn-in iter 634
# Burn-in iter 635
# Burn-in iter 636
# Burn-in iter 637
# Burn-in iter 638
# Burn-in iter 639
# Burn-in iter 640
# Burn-in iter 641
# Burn-in iter 642
# Burn-in iter 643
# Burn-in iter 644
# Burn-in iter 645
# Burn-in iter 646
# Burn-in iter 647
# Burn-in iter 648
# Burn-in iter 649
# Burn-in iter 650
# Burn-in iter 651
# Burn-in iter 652
# Burn-in iter 653
# Burn-in iter 654
# Burn-in iter 655
# Burn-in iter 656
# Burn-in iter 657
# Burn-in iter 658
# Burn-in iter 659
# Burn-in iter 660
# Burn-in iter 661
# Burn-in iter 662
# Burn-in iter 663
# Burn-in iter 664
# Burn-in iter 665
# Burn-in iter 666
# Burn-in iter 667
# Burn-in iter 668
# Burn-in iter 669
# Burn-in iter 670
# Burn-in iter 671
# Burn-in iter 672
# Burn-in iter 673
# Burn-in iter 674
# Burn-in iter 675
# Burn-in iter 676
# Burn-in iter 677
# Burn-in iter 678
# Burn-in iter 679
# Burn-in iter 680
# Burn-in iter 681
# Burn-in iter 682
# Burn-in iter 683
# Burn-in iter 684
# Burn-in iter 685
# Burn-in iter 686
# Burn-in iter 687
# Burn-in iter 688
# Burn-in iter 689
# Burn-in iter 690
# Burn-in iter 691
# Burn-in iter 692
# Burn-in iter 693
# Burn-in iter 694
# Burn-in iter 695
# Burn-in iter 696
# Burn-in iter 697
# Burn-in iter 698
# Burn-in iter 699
# Burn-in iter 700
# Burn-in iter 701
# Burn-in iter 702
# Burn-in iter 703
# Burn-in iter 704
# Burn-in iter 705
# Burn-in iter 706
# Burn-in iter 707
# Burn-in iter 708
# Burn-in iter 709
# Burn-in iter 710
# Burn-in iter 711
# Burn-in iter 712
# Burn-in iter 713
# Burn-in iter 714
# Burn-in iter 715
# Burn-in iter 716
# Burn-in iter 717
# Burn-in iter 718
# Burn-in iter 719
# Burn-in iter 720
# Burn-in iter 721
# Burn-in iter 722
# Burn-in iter 723
# Burn-in iter 724
# Burn-in iter 725
# Burn-in iter 726
# Burn-in iter 727
# Burn-in iter 728
# Burn-in iter 729
# Burn-in iter 730
# Burn-in iter 731
# Burn-in iter 732
# Burn-in iter 733
# Burn-in iter 734
# Burn-in iter 735
# Burn-in iter 736
# Burn-in iter 737
# Burn-in iter 738
# Burn-in iter 739
# Burn-in iter 740
# Burn-in iter 741
# Burn-in iter 742
# Burn-in iter 743
# Burn-in iter 744
# Burn-in iter 745
# Burn-in iter 746
# Burn-in iter 747
# Burn-in iter 748
# Burn-in iter 749
# Burn-in iter 750
# Burn-in iter 751
# Burn-in iter 752
# Burn-in iter 753
# Burn-in iter 754
# Burn-in iter 755
# Burn-in iter 756
# Burn-in iter 757
# Burn-in iter 758
# Burn-in iter 759
# Burn-in iter 760
# Burn-in iter 761
# Burn-in iter 762
# Burn-in iter 763
# Burn-in iter 764
# Burn-in iter 765
# Burn-in iter 766
# Burn-in iter 767
# Burn-in iter 768
# Burn-in iter 769
# Burn-in iter 770
# Burn-in iter 771
# Burn-in iter 772
# Burn-in iter 773
# Burn-in iter 774
# Burn-in iter 775
# Burn-in iter 776
# Burn-in iter 777
# Burn-in iter 778
# Burn-in iter 779
# Burn-in iter 780
# Burn-in iter 781
# Burn-in iter 782
# Burn-in iter 783
# Burn-in iter 784
# Burn-in iter 785
# Burn-in iter 786
# Burn-in iter 787
# Burn-in iter 788
# Burn-in iter 789
# Burn-in iter 790
# Burn-in iter 791
# Burn-in iter 792
# Burn-in iter 793
# Burn-in iter 794
# Burn-in iter 795
# Burn-in iter 796
# Burn-in iter 797
# Burn-in iter 798
# Burn-in iter 799
# Burn-in iter 800
# Burn-in iter 801
# Burn-in iter 802
# Burn-in iter 803
# Burn-in iter 804
# Burn-in iter 805
# Burn-in iter 806
# Burn-in iter 807
# Burn-in iter 808
# Burn-in iter 809
# Burn-in iter 810
# Burn-in iter 811
# Burn-in iter 812
# Burn-in iter 813
# Burn-in iter 814
# Burn-in iter 815
# Burn-in iter 816
# Burn-in iter 817
# Burn-in iter 818
# Burn-in iter 819
# Burn-in iter 820
# Burn-in iter 821
# Burn-in iter 822
# Burn-in iter 823
# Burn-in iter 824
# Burn-in iter 825
# Burn-in iter 826
# Burn-in iter 827
# Burn-in iter 828
# Burn-in iter 829
# Burn-in iter 830
# Burn-in iter 831
# Burn-in iter 832
# Burn-in iter 833
# Burn-in iter 834
# Burn-in iter 835
# Burn-in iter 836
# Burn-in iter 837
# Burn-in iter 838
# Burn-in iter 839
# Burn-in iter 840
# Burn-in iter 841
# Burn-in iter 842
# Burn-in iter 843
# Burn-in iter 844
# Burn-in iter 845
# Burn-in iter 846
# Burn-in iter 847
# Burn-in iter 848
# Burn-in iter 849
# Burn-in iter 850
# Burn-in iter 851
# Burn-in iter 852
# Burn-in iter 853
# Burn-in iter 854
# Burn-in iter 855
# Burn-in iter 856
# Burn-in iter 857
# Burn-in iter 858
# Burn-in iter 859
# Burn-in iter 860
# Burn-in iter 861
# Burn-in iter 862
# Burn-in iter 863
# Burn-in iter 864
# Burn-in iter 865
# Burn-in iter 866
# Burn-in iter 867
# Burn-in iter 868
# Burn-in iter 869
# Burn-in iter 870
# Burn-in iter 871
# Burn-in iter 872
# Burn-in iter 873
# Burn-in iter 874
# Burn-in iter 875
# Burn-in iter 876
# Burn-in iter 877
# Burn-in iter 878
# Burn-in iter 879
# Burn-in iter 880
# Burn-in iter 881
# Burn-in iter 882
# Burn-in iter 883
# Burn-in iter 884
# Burn-in iter 885
# Burn-in iter 886
# Burn-in iter 887
# Burn-in iter 888
# Burn-in iter 889
# Burn-in iter 890
# Burn-in iter 891
# Burn-in iter 892
# Burn-in iter 893
# Burn-in iter 894
# Burn-in iter 895
# Burn-in iter 896
# Burn-in iter 897
# Burn-in iter 898
# Burn-in iter 899
# Burn-in iter 900
# Burn-in iter 901
# Burn-in iter 902
# Burn-in iter 903
# Burn-in iter 904
# Burn-in iter 905
# Burn-in iter 906
# Burn-in iter 907
# Burn-in iter 908
# Burn-in iter 909
# Burn-in iter 910
# Burn-in iter 911
# Burn-in iter 912
# Burn-in iter 913
# Burn-in iter 914
# Burn-in iter 915
# Burn-in iter 916
# Burn-in iter 917
# Burn-in iter 918
# Burn-in iter 919
# Burn-in iter 920
# Burn-in iter 921
# Burn-in iter 922
# Burn-in iter 923
# Burn-in iter 924
# Burn-in iter 925
# Burn-in iter 926
# Burn-in iter 927
# Burn-in iter 928
# Burn-in iter 929
# Burn-in iter 930
# Burn-in iter 931
# Burn-in iter 932
# Burn-in iter 933
# Burn-in iter 934
# Burn-in iter 935
# Burn-in iter 936
# Burn-in iter 937
# Burn-in iter 938
# Burn-in iter 939
# Burn-in iter 940
# Burn-in iter 941
# Burn-in iter 942
# Burn-in iter 943
# Burn-in iter 944
# Burn-in iter 945
# Burn-in iter 946
# Burn-in iter 947
# Burn-in iter 948
# Burn-in iter 949
# Burn-in iter 950
# Burn-in iter 951
# Burn-in iter 952
# Burn-in iter 953
# Burn-in iter 954
# Burn-in iter 955
# Burn-in iter 956
# Burn-in iter 957
# Burn-in iter 958
# Burn-in iter 959
# Burn-in iter 960
# Burn-in iter 961
# Burn-in iter 962
# Burn-in iter 963
# Burn-in iter 964
# Burn-in iter 965
# Burn-in iter 966
# Burn-in iter 967
# Burn-in iter 968
# Burn-in iter 969
# Burn-in iter 970
# Burn-in iter 971
# Burn-in iter 972
# Burn-in iter 973
# Burn-in iter 974
# Burn-in iter 975
# Burn-in iter 976
# Burn-in iter 977
# Burn-in iter 978
# Burn-in iter 979
# Burn-in iter 980
# Burn-in iter 981
# Burn-in iter 982
# Burn-in iter 983
# Burn-in iter 984
# Burn-in iter 985
# Burn-in iter 986
# Burn-in iter 987
# Burn-in iter 988
# Burn-in iter 989
# Burn-in iter 990
# Burn-in iter 991
# Burn-in iter 992
# Burn-in iter 993
# Burn-in iter 994
# Burn-in iter 995
# Burn-in iter 996
# Burn-in iter 997
# Burn-in iter 998
# Burn-in iter 999
# Burn-in iter 1000
# Burn-in iter 1001
# Burn-in iter 1002
# Burn-in iter 1003
# Burn-in iter 1004
# Burn-in iter 1005
# Burn-in iter 1006
# Burn-in iter 1007
# Burn-in iter 1008
# Burn-in iter 1009
# Burn-in iter 1010
# Burn-in iter 1011
# Burn-in iter 1012
# Burn-in iter 1013
# Burn-in iter 1014
# Burn-in iter 1015
# Burn-in iter 1016
# Burn-in iter 1017
# Burn-in iter 1018
# Burn-in iter 1019
# Burn-in iter 1020
# Burn-in iter 1021
# Burn-in iter 1022
# Burn-in iter 1023
# Burn-in iter 1024
# Burn-in iter 1025
# Burn-in iter 1026
# Burn-in iter 1027
# Burn-in iter 1028
# Burn-in iter 1029
# Burn-in iter 1030
# Burn-in iter 1031
# Burn-in iter 1032
# Burn-in iter 1033
# Burn-in iter 1034
# Burn-in iter 1035
# Burn-in iter 1036
# Burn-in iter 1037
# Burn-in iter 1038
# Burn-in iter 1039
# Burn-in iter 1040
# Burn-in iter 1041
# Burn-in iter 1042
# Burn-in iter 1043
# Burn-in iter 1044
# Burn-in iter 1045
# Burn-in iter 1046
# Burn-in iter 1047
# Burn-in iter 1048
# Burn-in iter 1049
# Burn-in iter 1050
# Burn-in iter 1051
# Burn-in iter 1052
# Burn-in iter 1053
# Burn-in iter 1054
# Burn-in iter 1055
# Burn-in iter 1056
# Burn-in iter 1057
# Burn-in iter 1058
# Burn-in iter 1059
# Burn-in iter 1060
# Burn-in iter 1061
# Burn-in iter 1062
# Burn-in iter 1063
# Burn-in iter 1064
# Burn-in iter 1065
# Burn-in iter 1066
# Burn-in iter 1067
# Burn-in iter 1068
# Burn-in iter 1069
# Burn-in iter 1070
# Burn-in iter 1071
# Burn-in iter 1072
# Burn-in iter 1073
# Burn-in iter 1074
# Burn-in iter 1075
# Burn-in iter 1076
# Burn-in iter 1077
# Burn-in iter 1078
# Burn-in iter 1079
# Burn-in iter 1080
# Burn-in iter 1081
# Burn-in iter 1082
# Burn-in iter 1083
# Burn-in iter 1084
# Burn-in iter 1085
# Burn-in iter 1086
# Burn-in iter 1087
# Burn-in iter 1088
# Burn-in iter 1089
# Burn-in iter 1090
# Burn-in iter 1091
# Burn-in iter 1092
# Burn-in iter 1093
# Burn-in iter 1094
# Burn-in iter 1095
# Burn-in iter 1096
# Burn-in iter 1097
# Burn-in iter 1098
# Burn-in iter 1099
# Burn-in iter 1100
# Burn-in iter 1101
# Burn-in iter 1102
# Burn-in iter 1103
# Burn-in iter 1104
# Burn-in iter 1105
# Burn-in iter 1106
# Burn-in iter 1107
# Burn-in iter 1108
# Burn-in iter 1109
# Burn-in iter 1110
# Burn-in iter 1111
# Burn-in iter 1112
# Burn-in iter 1113
# Burn-in iter 1114
# Burn-in iter 1115
# Burn-in iter 1116
# Burn-in iter 1117
# Burn-in iter 1118
# Burn-in iter 1119
# Burn-in iter 1120
# Burn-in iter 1121
# Burn-in iter 1122
# Burn-in iter 1123
# Burn-in iter 1124
# Burn-in iter 1125
# Burn-in iter 1126
# Burn-in iter 1127
# Burn-in iter 1128
# Burn-in iter 1129
# Burn-in iter 1130
# Burn-in iter 1131
# Burn-in iter 1132
# Burn-in iter 1133
# Burn-in iter 1134
# Burn-in iter 1135
# Burn-in iter 1136
# Burn-in iter 1137
# Burn-in iter 1138
# Burn-in iter 1139
# Burn-in iter 1140
# Burn-in iter 1141
# Burn-in iter 1142
# Burn-in iter 1143
# Burn-in iter 1144
# Burn-in iter 1145
# Burn-in iter 1146
# Burn-in iter 1147
# Burn-in iter 1148
# Burn-in iter 1149
# Burn-in iter 1150
# Burn-in iter 1151
# Burn-in iter 1152
# Burn-in iter 1153
# Burn-in iter 1154
# Burn-in iter 1155
# Burn-in iter 1156
# Burn-in iter 1157
# Burn-in iter 1158
# Burn-in iter 1159
# Burn-in iter 1160
# Burn-in iter 1161
# Burn-in iter 1162
# Burn-in iter 1163
# Burn-in iter 1164
# Burn-in iter 1165
# Burn-in iter 1166
# Burn-in iter 1167
# Burn-in iter 1168
# Burn-in iter 1169
# Burn-in iter 1170
# Burn-in iter 1171
# Burn-in iter 1172
# Burn-in iter 1173
# Burn-in iter 1174
# Burn-in iter 1175
# Burn-in iter 1176
# Burn-in iter 1177
# Burn-in iter 1178
# Burn-in iter 1179
# Burn-in iter 1180
# Burn-in iter 1181
# Burn-in iter 1182
# Burn-in iter 1183
# Burn-in iter 1184
# Burn-in iter 1185
# Burn-in iter 1186
# Burn-in iter 1187
# Burn-in iter 1188
# Burn-in iter 1189
# Burn-in iter 1190
# Burn-in iter 1191
# Burn-in iter 1192
# Burn-in iter 1193
# Burn-in iter 1194
# Burn-in iter 1195
# Burn-in iter 1196
# Burn-in iter 1197
# Burn-in iter 1198
# Burn-in iter 1199
# Burn-in iter 1200
# Burn-in iter 1201
# Burn-in iter 1202
# Burn-in iter 1203
# Burn-in iter 1204
# Burn-in iter 1205
# Burn-in iter 1206
# Burn-in iter 1207
# Burn-in iter 1208
# Burn-in iter 1209
# Burn-in iter 1210
# Burn-in iter 1211
# Burn-in iter 1212
# Burn-in iter 1213
# Burn-in iter 1214
# Burn-in iter 1215
# Burn-in iter 1216
# Burn-in iter 1217
# Burn-in iter 1218
# Burn-in iter 1219
# Burn-in iter 1220
# Burn-in iter 1221
# Burn-in iter 1222
# Burn-in iter 1223
# Burn-in iter 1224
# Burn-in iter 1225
# Burn-in iter 1226
# Burn-in iter 1227
# Burn-in iter 1228
# Burn-in iter 1229
# Burn-in iter 1230
# Burn-in iter 1231
# Burn-in iter 1232
# Burn-in iter 1233
# Burn-in iter 1234
# Burn-in iter 1235
# Burn-in iter 1236
# Burn-in iter 1237
# Burn-in iter 1238
# Burn-in iter 1239
# Burn-in iter 1240
# Burn-in iter 1241
# Burn-in iter 1242
# Burn-in iter 1243
# Burn-in iter 1244
# Burn-in iter 1245
# Burn-in iter 1246
# Burn-in iter 1247
# Burn-in iter 1248
# Burn-in iter 1249
# Burn-in iter 1250
# Burn-in iter 1251
# Burn-in iter 1252
# Burn-in iter 1253
# Burn-in iter 1254
# Burn-in iter 1255
# Burn-in iter 1256
# Burn-in iter 1257
# Burn-in iter 1258
# Burn-in iter 1259
# Burn-in iter 1260
# Burn-in iter 1261
# Burn-in iter 1262
# Burn-in iter 1263
# Burn-in iter 1264
# Burn-in iter 1265
# Burn-in iter 1266
# Burn-in iter 1267
# Burn-in iter 1268
# Burn-in iter 1269
# Burn-in iter 1270
# Burn-in iter 1271
# Burn-in iter 1272
# Burn-in iter 1273
# Burn-in iter 1274
# Burn-in iter 1275
# Burn-in iter 1276
# Burn-in iter 1277
# Burn-in iter 1278
# Burn-in iter 1279
# Burn-in iter 1280
# Burn-in iter 1281
# Burn-in iter 1282
# Burn-in iter 1283
# Burn-in iter 1284
# Burn-in iter 1285
# Burn-in iter 1286
# Burn-in iter 1287
# Burn-in iter 1288
# Burn-in iter 1289
# Burn-in iter 1290
# Burn-in iter 1291
# Burn-in iter 1292
# Burn-in iter 1293
# Burn-in iter 1294
# Burn-in iter 1295
# Burn-in iter 1296
# Burn-in iter 1297
# Burn-in iter 1298
# Burn-in iter 1299
# Burn-in iter 1300
# Burn-in iter 1301
# Burn-in iter 1302
# Burn-in iter 1303
# Burn-in iter 1304
# Burn-in iter 1305
# Burn-in iter 1306
# Burn-in iter 1307
# Burn-in iter 1308
# Burn-in iter 1309
# Burn-in iter 1310
# Burn-in iter 1311
# Burn-in iter 1312
# Burn-in iter 1313
# Burn-in iter 1314
# Burn-in iter 1315
# Burn-in iter 1316
# Burn-in iter 1317
# Burn-in iter 1318
# Burn-in iter 1319
# Burn-in iter 1320
# Burn-in iter 1321
# Burn-in iter 1322
# Burn-in iter 1323
# Burn-in iter 1324
# Burn-in iter 1325
# Burn-in iter 1326
# Burn-in iter 1327
# Burn-in iter 1328
# Burn-in iter 1329
# Burn-in iter 1330
# Burn-in iter 1331
# Burn-in iter 1332
# Burn-in iter 1333
# Burn-in iter 1334
# Burn-in iter 1335
# Burn-in iter 1336
# Burn-in iter 1337
# Burn-in iter 1338
# Burn-in iter 1339
# Burn-in iter 1340
# Burn-in iter 1341
# Burn-in iter 1342
# Burn-in iter 1343
# Burn-in iter 1344
# Burn-in iter 1345
# Burn-in iter 1346
# Burn-in iter 1347
# Burn-in iter 1348
# Burn-in iter 1349
# Burn-in iter 1350
# Burn-in iter 1351
# Burn-in iter 1352
# Burn-in iter 1353
# Burn-in iter 1354
# Burn-in iter 1355
# Burn-in iter 1356
# Burn-in iter 1357
# Burn-in iter 1358
# Burn-in iter 1359
# Burn-in iter 1360
# Burn-in iter 1361
# Burn-in iter 1362
# Burn-in iter 1363
# Burn-in iter 1364
# Burn-in iter 1365
# Burn-in iter 1366
# Burn-in iter 1367
# Burn-in iter 1368
# Burn-in iter 1369
# Burn-in iter 1370
# Burn-in iter 1371
# Burn-in iter 1372
# Burn-in iter 1373
# Burn-in iter 1374
# Burn-in iter 1375
# Burn-in iter 1376
# Burn-in iter 1377
# Burn-in iter 1378
# Burn-in iter 1379
# Burn-in iter 1380
# Burn-in iter 1381
# Burn-in iter 1382
# Burn-in iter 1383
# Burn-in iter 1384
# Burn-in iter 1385
# Burn-in iter 1386
# Burn-in iter 1387
# Burn-in iter 1388
# Burn-in iter 1389
# Burn-in iter 1390
# Burn-in iter 1391
# Burn-in iter 1392
# Burn-in iter 1393
# Burn-in iter 1394
# Burn-in iter 1395
# Burn-in iter 1396
# Burn-in iter 1397
# Burn-in iter 1398
# Burn-in iter 1399
# Burn-in iter 1400
# Burn-in iter 1401
# Burn-in iter 1402
# Burn-in iter 1403
# Burn-in iter 1404
# Burn-in iter 1405
# Burn-in iter 1406
# Burn-in iter 1407
# Burn-in iter 1408
# Burn-in iter 1409
# Burn-in iter 1410
# Burn-in iter 1411
# Burn-in iter 1412
# Burn-in iter 1413
# Burn-in iter 1414
# Burn-in iter 1415
# Burn-in iter 1416
# Burn-in iter 1417
# Burn-in iter 1418
# Burn-in iter 1419
# Burn-in iter 1420
# Burn-in iter 1421
# Burn-in iter 1422
# Burn-in iter 1423
# Burn-in iter 1424
# Burn-in iter 1425
# Burn-in iter 1426
# Burn-in iter 1427
# Burn-in iter 1428
# Burn-in iter 1429
# Burn-in iter 1430
# Burn-in iter 1431
# Burn-in iter 1432
# Burn-in iter 1433
# Burn-in iter 1434
# Burn-in iter 1435
# Burn-in iter 1436
# Burn-in iter 1437
# Burn-in iter 1438
# Burn-in iter 1439
# Burn-in iter 1440
# Burn-in iter 1441
# Burn-in iter 1442
# Burn-in iter 1443
# Burn-in iter 1444
# Burn-in iter 1445
# Burn-in iter 1446
# Burn-in iter 1447
# Burn-in iter 1448
# Burn-in iter 1449
# Burn-in iter 1450
# Burn-in iter 1451
# Burn-in iter 1452
# Burn-in iter 1453
# Burn-in iter 1454
# Burn-in iter 1455
# Burn-in iter 1456
# Burn-in iter 1457
# Burn-in iter 1458
# Burn-in iter 1459
# Burn-in iter 1460
# Burn-in iter 1461
# Burn-in iter 1462
# Burn-in iter 1463
# Burn-in iter 1464
# Burn-in iter 1465
# Burn-in iter 1466
# Burn-in iter 1467
# Burn-in iter 1468
# Burn-in iter 1469
# Burn-in iter 1470
# Burn-in iter 1471
# Burn-in iter 1472
# Burn-in iter 1473
# Burn-in iter 1474
# Burn-in iter 1475
# Burn-in iter 1476
# Burn-in iter 1477
# Burn-in iter 1478
# Burn-in iter 1479
# Burn-in iter 1480
# Burn-in iter 1481
# Burn-in iter 1482
# Burn-in iter 1483
# Burn-in iter 1484
# Burn-in iter 1485
# Burn-in iter 1486
# Burn-in iter 1487
# Burn-in iter 1488
# Burn-in iter 1489
# Burn-in iter 1490
# Burn-in iter 1491
# Burn-in iter 1492
# Burn-in iter 1493
# Burn-in iter 1494
# Burn-in iter 1495
# Burn-in iter 1496
# Burn-in iter 1497
# Burn-in iter 1498
# Burn-in iter 1499
# Burn-in iter 1500
# Burn-in iter 1501
# Burn-in iter 1502
# Burn-in iter 1503
# Burn-in iter 1504
# Burn-in iter 1505
# Burn-in iter 1506
# Burn-in iter 1507
# Burn-in iter 1508
# Burn-in iter 1509
# Burn-in iter 1510
# Burn-in iter 1511
# Burn-in iter 1512
# Burn-in iter 1513
# Burn-in iter 1514
# Burn-in iter 1515
# Burn-in iter 1516
# Burn-in iter 1517
# Burn-in iter 1518
# Burn-in iter 1519
# Burn-in iter 1520
# Burn-in iter 1521
# Burn-in iter 1522
# Burn-in iter 1523
# Burn-in iter 1524
# Burn-in iter 1525
# Burn-in iter 1526
# Burn-in iter 1527
# Burn-in iter 1528
# Burn-in iter 1529
# Burn-in iter 1530
# Burn-in iter 1531
# Burn-in iter 1532
# Burn-in iter 1533
# Burn-in iter 1534
# Burn-in iter 1535
# Burn-in iter 1536
# Burn-in iter 1537
# Burn-in iter 1538
# Burn-in iter 1539
# Burn-in iter 1540
# Burn-in iter 1541
# Burn-in iter 1542
# Burn-in iter 1543
# Burn-in iter 1544
# Burn-in iter 1545
# Burn-in iter 1546
# Burn-in iter 1547
# Burn-in iter 1548
# Burn-in iter 1549
# Burn-in iter 1550
# Burn-in iter 1551
# Burn-in iter 1552
# Burn-in iter 1553
# Burn-in iter 1554
# Burn-in iter 1555
# Burn-in iter 1556
# Burn-in iter 1557
# Burn-in iter 1558
# Burn-in iter 1559
# Burn-in iter 1560
# Burn-in iter 1561
# Burn-in iter 1562
# Burn-in iter 1563
# Burn-in iter 1564
# Burn-in iter 1565
# Burn-in iter 1566
# Burn-in iter 1567
# Burn-in iter 1568
# Burn-in iter 1569
# Burn-in iter 1570
# Burn-in iter 1571
# Burn-in iter 1572
# Burn-in iter 1573
# Burn-in iter 1574
# Burn-in iter 1575
# Burn-in iter 1576
# Burn-in iter 1577
# Burn-in iter 1578
# Burn-in iter 1579
# Burn-in iter 1580
# Burn-in iter 1581
# Burn-in iter 1582
# Burn-in iter 1583
# Burn-in iter 1584
# Burn-in iter 1585
# Burn-in iter 1586
# Burn-in iter 1587
# Burn-in iter 1588
# Burn-in iter 1589
# Burn-in iter 1590
# Burn-in iter 1591
# Burn-in iter 1592
# Burn-in iter 1593
# Burn-in iter 1594
# Burn-in iter 1595
# Burn-in iter 1596
# Burn-in iter 1597
# Burn-in iter 1598
# Burn-in iter 1599
# Burn-in iter 1600
# Burn-in iter 1601
# Burn-in iter 1602
# Burn-in iter 1603
# Burn-in iter 1604
# Burn-in iter 1605
# Burn-in iter 1606
# Burn-in iter 1607
# Burn-in iter 1608
# Burn-in iter 1609
# Burn-in iter 1610
# Burn-in iter 1611
# Burn-in iter 1612
# Burn-in iter 1613
# Burn-in iter 1614
# Burn-in iter 1615
# Burn-in iter 1616
# Burn-in iter 1617
# Burn-in iter 1618
# Burn-in iter 1619
# Burn-in iter 1620
# Burn-in iter 1621
# Burn-in iter 1622
# Burn-in iter 1623
# Burn-in iter 1624
# Burn-in iter 1625
# Burn-in iter 1626
# Burn-in iter 1627
# Burn-in iter 1628
# Burn-in iter 1629
# Burn-in iter 1630
# Burn-in iter 1631
# Burn-in iter 1632
# Burn-in iter 1633
# Burn-in iter 1634
# Burn-in iter 1635
# Burn-in iter 1636
# Burn-in iter 1637
# Burn-in iter 1638
# Burn-in iter 1639
# Burn-in iter 1640
# Burn-in iter 1641
# Burn-in iter 1642
# Burn-in iter 1643
# Burn-in iter 1644
# Burn-in iter 1645
# Burn-in iter 1646
# Burn-in iter 1647
# Burn-in iter 1648
# Burn-in iter 1649
# Burn-in iter 1650
# Burn-in iter 1651
# Burn-in iter 1652
# Burn-in iter 1653
# Burn-in iter 1654
# Burn-in iter 1655
# Burn-in iter 1656
# Burn-in iter 1657
# Burn-in iter 1658
# Burn-in iter 1659
# Burn-in iter 1660
# Burn-in iter 1661
# Burn-in iter 1662
# Burn-in iter 1663
# Burn-in iter 1664
# Burn-in iter 1665
# Burn-in iter 1666
# Burn-in iter 1667
# Burn-in iter 1668
# Burn-in iter 1669
# Burn-in iter 1670
# Burn-in iter 1671
# Burn-in iter 1672
# Burn-in iter 1673
# Burn-in iter 1674
# Burn-in iter 1675
# Burn-in iter 1676
# Burn-in iter 1677
# Burn-in iter 1678
# Burn-in iter 1679
# Burn-in iter 1680
# Burn-in iter 1681
# Burn-in iter 1682
# Burn-in iter 1683
# Burn-in iter 1684
# Burn-in iter 1685
# Burn-in iter 1686
# Burn-in iter 1687
# Burn-in iter 1688
# Burn-in iter 1689
# Burn-in iter 1690
# Burn-in iter 1691
# Burn-in iter 1692
# Burn-in iter 1693
# Burn-in iter 1694
# Burn-in iter 1695
# Burn-in iter 1696
# Burn-in iter 1697
# Burn-in iter 1698
# Burn-in iter 1699
# Burn-in iter 1700
# Burn-in iter 1701
# Burn-in iter 1702
# Burn-in iter 1703
# Burn-in iter 1704
# Burn-in iter 1705
# Burn-in iter 1706
# Burn-in iter 1707
# Burn-in iter 1708
# Burn-in iter 1709
# Burn-in iter 1710
# Burn-in iter 1711
# Burn-in iter 1712
# Burn-in iter 1713
# Burn-in iter 1714
# Burn-in iter 1715
# Burn-in iter 1716
# Burn-in iter 1717
# Burn-in iter 1718
# Burn-in iter 1719
# Burn-in iter 1720
# Burn-in iter 1721
# Burn-in iter 1722
# Burn-in iter 1723
# Burn-in iter 1724
# Burn-in iter 1725
# Burn-in iter 1726
# Burn-in iter 1727
# Burn-in iter 1728
# Burn-in iter 1729
# Burn-in iter 1730
# Burn-in iter 1731
# Burn-in iter 1732
# Burn-in iter 1733
# Burn-in iter 1734
# Burn-in iter 1735
# Burn-in iter 1736
# Burn-in iter 1737
# Burn-in iter 1738
# Burn-in iter 1739
# Burn-in iter 1740
# Burn-in iter 1741
# Burn-in iter 1742
# Burn-in iter 1743
# Burn-in iter 1744
# Burn-in iter 1745
# Burn-in iter 1746
# Burn-in iter 1747
# Burn-in iter 1748
# Burn-in iter 1749
# Burn-in iter 1750
# Burn-in iter 1751
# Burn-in iter 1752
# Burn-in iter 1753
# Burn-in iter 1754
# Burn-in iter 1755
# Burn-in iter 1756
# Burn-in iter 1757
# Burn-in iter 1758
# Burn-in iter 1759
# Burn-in iter 1760
# Burn-in iter 1761
# Burn-in iter 1762
# Burn-in iter 1763
# Burn-in iter 1764
# Burn-in iter 1765
# Burn-in iter 1766
# Burn-in iter 1767
# Burn-in iter 1768
# Burn-in iter 1769
# Burn-in iter 1770
# Burn-in iter 1771
# Burn-in iter 1772
# Burn-in iter 1773
# Burn-in iter 1774
# Burn-in iter 1775
# Burn-in iter 1776
# Burn-in iter 1777
# Burn-in iter 1778
# Burn-in iter 1779
# Burn-in iter 1780
# Burn-in iter 1781
# Burn-in iter 1782
# Burn-in iter 1783
# Burn-in iter 1784
# Burn-in iter 1785
# Burn-in iter 1786
# Burn-in iter 1787
# Burn-in iter 1788
# Burn-in iter 1789
# Burn-in iter 1790
# Burn-in iter 1791
# Burn-in iter 1792
# Burn-in iter 1793
# Burn-in iter 1794
# Burn-in iter 1795
# Burn-in iter 1796
# Burn-in iter 1797
# Burn-in iter 1798
# Burn-in iter 1799
# Burn-in iter 1800
# Burn-in iter 1801
# Burn-in iter 1802
# Burn-in iter 1803
# Burn-in iter 1804
# Burn-in iter 1805
# Burn-in iter 1806
# Burn-in iter 1807
# Burn-in iter 1808
# Burn-in iter 1809
# Burn-in iter 1810
# Burn-in iter 1811
# Burn-in iter 1812
# Burn-in iter 1813
# Burn-in iter 1814
# Burn-in iter 1815
# Burn-in iter 1816
# Burn-in iter 1817
# Burn-in iter 1818
# Burn-in iter 1819
# Burn-in iter 1820
# Burn-in iter 1821
# Burn-in iter 1822
# Burn-in iter 1823
# Burn-in iter 1824
# Burn-in iter 1825
# Burn-in iter 1826
# Burn-in iter 1827
# Burn-in iter 1828
# Burn-in iter 1829
# Burn-in iter 1830
# Burn-in iter 1831
# Burn-in iter 1832
# Burn-in iter 1833
# Burn-in iter 1834
# Burn-in iter 1835
# Burn-in iter 1836
# Burn-in iter 1837
# Burn-in iter 1838
# Burn-in iter 1839
# Burn-in iter 1840
# Burn-in iter 1841
# Burn-in iter 1842
# Burn-in iter 1843
# Burn-in iter 1844
# Burn-in iter 1845
# Burn-in iter 1846
# Burn-in iter 1847
# Burn-in iter 1848
# Burn-in iter 1849
# Burn-in iter 1850
# Burn-in iter 1851
# Burn-in iter 1852
# Burn-in iter 1853
# Burn-in iter 1854
# Burn-in iter 1855
# Burn-in iter 1856
# Burn-in iter 1857
# Burn-in iter 1858
# Burn-in iter 1859
# Burn-in iter 1860
# Burn-in iter 1861
# Burn-in iter 1862
# Burn-in iter 1863
# Burn-in iter 1864
# Burn-in iter 1865
# Burn-in iter 1866
# Burn-in iter 1867
# Burn-in iter 1868
# Burn-in iter 1869
# Burn-in iter 1870
# Burn-in iter 1871
# Burn-in iter 1872
# Burn-in iter 1873
# Burn-in iter 1874
# Burn-in iter 1875
# Burn-in iter 1876
# Burn-in iter 1877
# Burn-in iter 1878
# Burn-in iter 1879
# Burn-in iter 1880
# Burn-in iter 1881
# Burn-in iter 1882
# Burn-in iter 1883
# Burn-in iter 1884
# Burn-in iter 1885
# Burn-in iter 1886
# Burn-in iter 1887
# Burn-in iter 1888
# Burn-in iter 1889
# Burn-in iter 1890
# Burn-in iter 1891
# Burn-in iter 1892
# Burn-in iter 1893
# Burn-in iter 1894
# Burn-in iter 1895
# Burn-in iter 1896
# Burn-in iter 1897
# Burn-in iter 1898
# Burn-in iter 1899
# Burn-in iter 1900
# Burn-in iter 1901
# Burn-in iter 1902
# Burn-in iter 1903
# Burn-in iter 1904
# Burn-in iter 1905
# Burn-in iter 1906
# Burn-in iter 1907
# Burn-in iter 1908
# Burn-in iter 1909
# Burn-in iter 1910
# Burn-in iter 1911
# Burn-in iter 1912
# Burn-in iter 1913
# Burn-in iter 1914
# Burn-in iter 1915
# Burn-in iter 1916
# Burn-in iter 1917
# Burn-in iter 1918
# Burn-in iter 1919
# Burn-in iter 1920
# Burn-in iter 1921
# Burn-in iter 1922
# Burn-in iter 1923
# Burn-in iter 1924
# Burn-in iter 1925
# Burn-in iter 1926
# Burn-in iter 1927
# Burn-in iter 1928
# Burn-in iter 1929
# Burn-in iter 1930
# Burn-in iter 1931
# Burn-in iter 1932
# Burn-in iter 1933
# Burn-in iter 1934
# Burn-in iter 1935
# Burn-in iter 1936
# Burn-in iter 1937
# Burn-in iter 1938
# Burn-in iter 1939
# Burn-in iter 1940
# Burn-in iter 1941
# Burn-in iter 1942
# Burn-in iter 1943
# Burn-in iter 1944
# Burn-in iter 1945
# Burn-in iter 1946
# Burn-in iter 1947
# Burn-in iter 1948
# Burn-in iter 1949
# Burn-in iter 1950
# Burn-in iter 1951
# Burn-in iter 1952
# Burn-in iter 1953
# Burn-in iter 1954
# Burn-in iter 1955
# Burn-in iter 1956
# Burn-in iter 1957
# Burn-in iter 1958
# Burn-in iter 1959
# Burn-in iter 1960
# Burn-in iter 1961
# Burn-in iter 1962
# Burn-in iter 1963
# Burn-in iter 1964
# Burn-in iter 1965
# Burn-in iter 1966
# Burn-in iter 1967
# Burn-in iter 1968
# Burn-in iter 1969
# Burn-in iter 1970
# Burn-in iter 1971
# Burn-in iter 1972
# Burn-in iter 1973
# Burn-in iter 1974
# Burn-in iter 1975
# Burn-in iter 1976
# Burn-in iter 1977
# Burn-in iter 1978
# Burn-in iter 1979
# Burn-in iter 1980
# Burn-in iter 1981
# Burn-in iter 1982
# Burn-in iter 1983
# Burn-in iter 1984
# Burn-in iter 1985
# Burn-in iter 1986
# Burn-in iter 1987
# Burn-in iter 1988
# Burn-in iter 1989
# Burn-in iter 1990
# Burn-in iter 1991
# Burn-in iter 1992
# Burn-in iter 1993
# Burn-in iter 1994
# Burn-in iter 1995
# Burn-in iter 1996
# Burn-in iter 1997
# Burn-in iter 1998
# Burn-in iter 1999
# Burn-in iter 2000
# Sampling phase started
# Sample iter: 1
# Sample iter: 2
# Sample iter: 3
# Sample iter: 4
# Sample iter: 5
# Sample iter: 6
# Sample iter: 7
# Sample iter: 8
# Sample iter: 9
# Sample iter: 10
# Sample iter: 11
# Sample iter: 12
# Sample iter: 13
# Sample iter: 14
# Sample iter: 15
# Sample iter: 16
# Sample iter: 17
# Sample iter: 18
# Sample iter: 19
# Sample iter: 20
# Sample iter: 21
# Sample iter: 22
# Sample iter: 23
# Sample iter: 24
# Sample iter: 25
# Sample iter: 26
# Sample iter: 27
# Sample iter: 28
# Sample iter: 29
# Sample iter: 30
# Sample iter: 31
# Sample iter: 32
# Sample iter: 33
# Sample iter: 34
# Sample iter: 35
# Sample iter: 36
# Sample iter: 37
# Sample iter: 38
# Sample iter: 39
# Sample iter: 40
# Sample iter: 41
# Sample iter: 42
# Sample iter: 43
# Sample iter: 44
# Sample iter: 45
# Sample iter: 46
# Sample iter: 47
# Sample iter: 48
# Sample iter: 49
# Sample iter: 50
# Sample iter: 51
# Sample iter: 52
# Sample iter: 53
# Sample iter: 54
# Sample iter: 55
# Sample iter: 56
# Sample iter: 57
# Sample iter: 58
# Sample iter: 59
# Sample iter: 60
# Sample iter: 61
# Sample iter: 62
# Sample iter: 63
# Sample iter: 64
# Sample iter: 65
# Sample iter: 66
# Sample iter: 67
# Sample iter: 68
# Sample iter: 69
# Sample iter: 70
# Sample iter: 71
# Sample iter: 72
# Sample iter: 73
# Sample iter: 74
# Sample iter: 75
# Sample iter: 76
# Sample iter: 77
# Sample iter: 78
# Sample iter: 79
# Sample iter: 80
# Sample iter: 81
# Sample iter: 82
# Sample iter: 83
# Sample iter: 84
# Sample iter: 85
# Sample iter: 86
# Sample iter: 87
# Sample iter: 88
# Sample iter: 89
# Sample iter: 90
# Sample iter: 91
# Sample iter: 92
# Sample iter: 93
# Sample iter: 94
# Sample iter: 95
# Sample iter: 96
# Sample iter: 97
# Sample iter: 98
# Sample iter: 99
# Sample iter: 100
# Sample iter: 101
# Sample iter: 102
# Sample iter: 103
# Sample iter: 104
# Sample iter: 105
# Sample iter: 106
# Sample iter: 107
# Sample iter: 108
# Sample iter: 109
# Sample iter: 110
# Sample iter: 111
# Sample iter: 112
# Sample iter: 113
# Sample iter: 114
# Sample iter: 115
# Sample iter: 116
# Sample iter: 117
# Sample iter: 118
# Sample iter: 119
# Sample iter: 120
# Sample iter: 121
# Sample iter: 122
# Sample iter: 123
# Sample iter: 124
# Sample iter: 125
# Sample iter: 126
# Sample iter: 127
# Sample iter: 128
# Sample iter: 129
# Sample iter: 130
# Sample iter: 131
# Sample iter: 132
# Sample iter: 133
# Sample iter: 134
# Sample iter: 135
# Sample iter: 136
# Sample iter: 137
# Sample iter: 138
# Sample iter: 139
# Sample iter: 140
# Sample iter: 141
# Sample iter: 142
# Sample iter: 143
# Sample iter: 144
# Sample iter: 145
# Sample iter: 146
# Sample iter: 147
# Sample iter: 148
# Sample iter: 149
# Sample iter: 150
# Sample iter: 151
# Sample iter: 152
# Sample iter: 153
# Sample iter: 154
# Sample iter: 155
# Sample iter: 156
# Sample iter: 157
# Sample iter: 158
# Sample iter: 159
# Sample iter: 160
# Sample iter: 161
# Sample iter: 162
# Sample iter: 163
# Sample iter: 164
# Sample iter: 165
# Sample iter: 166
# Sample iter: 167
# Sample iter: 168
# Sample iter: 169
# Sample iter: 170
# Sample iter: 171
# Sample iter: 172
# Sample iter: 173
# Sample iter: 174
# Sample iter: 175
# Sample iter: 176
# Sample iter: 177
# Sample iter: 178
# Sample iter: 179
# Sample iter: 180
# Sample iter: 181
# Sample iter: 182
# Sample iter: 183
# Sample iter: 184
# Sample iter: 185
# Sample iter: 186
# Sample iter: 187
# Sample iter: 188
# Sample iter: 189
# Sample iter: 190
# Sample iter: 191
# Sample iter: 192
# Sample iter: 193
# Sample iter: 194
# Sample iter: 195
# Sample iter: 196
# Sample iter: 197
# Sample iter: 198
# Sample iter: 199
# Sample iter: 200
# Sample iter: 201
# Sample iter: 202
# Sample iter: 203
# Sample iter: 204
# Sample iter: 205
# Sample iter: 206
# Sample iter: 207
# Sample iter: 208
# Sample iter: 209
# Sample iter: 210
# Sample iter: 211
# Sample iter: 212
# Sample iter: 213
# Sample iter: 214
# Sample iter: 215
# Sample iter: 216
# Sample iter: 217
# Sample iter: 218
# Sample iter: 219
# Sample iter: 220
# Sample iter: 221
# Sample iter: 222
# Sample iter: 223
# Sample iter: 224
# Sample iter: 225
# Sample iter: 226
# Sample iter: 227
# Sample iter: 228
# Sample iter: 229
# Sample iter: 230
# Sample iter: 231
# Sample iter: 232
# Sample iter: 233
# Sample iter: 234
# Sample iter: 235
# Sample iter: 236
# Sample iter: 237
# Sample iter: 238
# Sample iter: 239
# Sample iter: 240
# Sample iter: 241
# Sample iter: 242
# Sample iter: 243
# Sample iter: 244
# Sample iter: 245
# Sample iter: 246
# Sample iter: 247
# Sample iter: 248
# Sample iter: 249
# Sample iter: 250
# Sample iter: 251
# Sample iter: 252
# Sample iter: 253
# Sample iter: 254
# Sample iter: 255
# Sample iter: 256
# Sample iter: 257
# Sample iter: 258
# Sample iter: 259
# Sample iter: 260
# Sample iter: 261
# Sample iter: 262
# Sample iter: 263
# Sample iter: 264
# Sample iter: 265
# Sample iter: 266
# Sample iter: 267
# Sample iter: 268
# Sample iter: 269
# Sample iter: 270
# Sample iter: 271
# Sample iter: 272
# Sample iter: 273
# Sample iter: 274
# Sample iter: 275
# Sample iter: 276
# Sample iter: 277
# Sample iter: 278
# Sample iter: 279
# Sample iter: 280
# Sample iter: 281
# Sample iter: 282
# Sample iter: 283
# Sample iter: 284
# Sample iter: 285
# Sample iter: 286
# Sample iter: 287
# Sample iter: 288
# Sample iter: 289
# Sample iter: 290
# Sample iter: 291
# Sample iter: 292
# Sample iter: 293
# Sample iter: 294
# Sample iter: 295
# Sample iter: 296
# Sample iter: 297
# Sample iter: 298
# Sample iter: 299
# Sample iter: 300
# Sample iter: 301
# Sample iter: 302
# Sample iter: 303
# Sample iter: 304
# Sample iter: 305
# Sample iter: 306
# Sample iter: 307
# Sample iter: 308
# Sample iter: 309
# Sample iter: 310
# Sample iter: 311
# Sample iter: 312
# Sample iter: 313
# Sample iter: 314
# Sample iter: 315
# Sample iter: 316
# Sample iter: 317
# Sample iter: 318
# Sample iter: 319
# Sample iter: 320
# Sample iter: 321
# Sample iter: 322
# Sample iter: 323
# Sample iter: 324
# Sample iter: 325
# Sample iter: 326
# Sample iter: 327
# Sample iter: 328
# Sample iter: 329
# Sample iter: 330
# Sample iter: 331
# Sample iter: 332
# Sample iter: 333
# Sample iter: 334
# Sample iter: 335
# Sample iter: 336
# Sample iter: 337
# Sample iter: 338
# Sample iter: 339
# Sample iter: 340
# Sample iter: 341
# Sample iter: 342
# Sample iter: 343
# Sample iter: 344
# Sample iter: 345
# Sample iter: 346
# Sample iter: 347
# Sample iter: 348
# Sample iter: 349
# Sample iter: 350
# Sample iter: 351
# Sample iter: 352
# Sample iter: 353
# Sample iter: 354
# Sample iter: 355
# Sample iter: 356
# Sample iter: 357
# Sample iter: 358
# Sample iter: 359
# Sample iter: 360
# Sample iter: 361
# Sample iter: 362
# Sample iter: 363
# Sample iter: 364
# Sample iter: 365
# Sample iter: 366
# Sample iter: 367
# Sample iter: 368
# Sample iter: 369
# Sample iter: 370
# Sample iter: 371
# Sample iter: 372
# Sample iter: 373
# Sample iter: 374
# Sample iter: 375
# Sample iter: 376
# Sample iter: 377
# Sample iter: 378
# Sample iter: 379
# Sample iter: 380
# Sample iter: 381
# Sample iter: 382
# Sample iter: 383
# Sample iter: 384
# Sample iter: 385
# Sample iter: 386
# Sample iter: 387
# Sample iter: 388
# Sample iter: 389
# Sample iter: 390
# Sample iter: 391
# Sample iter: 392
# Sample iter: 393
# Sample iter: 394
# Sample iter: 395
# Sample iter: 396
# Sample iter: 397
# Sample iter: 398
# Sample iter: 399
# Sample iter: 400
# Sample iter: 401
# Sample iter: 402
# Sample iter: 403
# Sample iter: 404
# Sample iter: 405
# Sample iter: 406
# Sample iter: 407
# Sample iter: 408
# Sample iter: 409
# Sample iter: 410
# Sample iter: 411
# Sample iter: 412
# Sample iter: 413
# Sample iter: 414
# Sample iter: 415
# Sample iter: 416
# Sample iter: 417
# Sample iter: 418
# Sample iter: 419
# Sample iter: 420
# Sample iter: 421
# Sample iter: 422
# Sample iter: 423
# Sample iter: 424
# Sample iter: 425
# Sample iter: 426
# Sample iter: 427
# Sample iter: 428
# Sample iter: 429
# Sample iter: 430
# Sample iter: 431
# Sample iter: 432
# Sample iter: 433
# Sample iter: 434
# Sample iter: 435
# Sample iter: 436
# Sample iter: 437
# Sample iter: 438
# Sample iter: 439
# Sample iter: 440
# Sample iter: 441
# Sample iter: 442
# Sample iter: 443
# Sample iter: 444
# Sample iter: 445
# Sample iter: 446
# Sample iter: 447
# Sample iter: 448
# Sample iter: 449
# Sample iter: 450
# Sample iter: 451
# Sample iter: 452
# Sample iter: 453
# Sample iter: 454
# Sample iter: 455
# Sample iter: 456
# Sample iter: 457
# Sample iter: 458
# Sample iter: 459
# Sample iter: 460
# Sample iter: 461
# Sample iter: 462
# Sample iter: 463
# Sample iter: 464
# Sample iter: 465
# Sample iter: 466
# Sample iter: 467
# Sample iter: 468
# Sample iter: 469
# Sample iter: 470
# Sample iter: 471
# Sample iter: 472
# Sample iter: 473
# Sample iter: 474
# Sample iter: 475
# Sample iter: 476
# Sample iter: 477
# Sample iter: 478
# Sample iter: 479
# Sample iter: 480
# Sample iter: 481
# Sample iter: 482
# Sample iter: 483
# Sample iter: 484
# Sample iter: 485
# Sample iter: 486
# Sample iter: 487
# Sample iter: 488
# Sample iter: 489
# Sample iter: 490
# Sample iter: 491
# Sample iter: 492
# Sample iter: 493
# Sample iter: 494
# Sample iter: 495
# Sample iter: 496
# Sample iter: 497
# Sample iter: 498
# Sample iter: 499
# Sample iter: 500
# Sample iter: 501
# Sample iter: 502
# Sample iter: 503
# Sample iter: 504
# Sample iter: 505
# Sample iter: 506
# Sample iter: 507
# Sample iter: 508
# Sample iter: 509
# Sample iter: 510
# Sample iter: 511
# Sample iter: 512
# Sample iter: 513
# Sample iter: 514
# Sample iter: 515
# Sample iter: 516
# Sample iter: 517
# Sample iter: 518
# Sample iter: 519
# Sample iter: 520
# Sample iter: 521
# Sample iter: 522
# Sample iter: 523
# Sample iter: 524
# Sample iter: 525
# Sample iter: 526
# Sample iter: 527
# Sample iter: 528
# Sample iter: 529
# Sample iter: 530
# Sample iter: 531
# Sample iter: 532
# Sample iter: 533
# Sample iter: 534
# Sample iter: 535
# Sample iter: 536
# Sample iter: 537
# Sample iter: 538
# Sample iter: 539
# Sample iter: 540
# Sample iter: 541
# Sample iter: 542
# Sample iter: 543
# Sample iter: 544
# Sample iter: 545
# Sample iter: 546
# Sample iter: 547
# Sample iter: 548
# Sample iter: 549
# Sample iter: 550
# Sample iter: 551
# Sample iter: 552
# Sample iter: 553
# Sample iter: 554
# Sample iter: 555
# Sample iter: 556
# Sample iter: 557
# Sample iter: 558
# Sample iter: 559
# Sample iter: 560
# Sample iter: 561
# Sample iter: 562
# Sample iter: 563
# Sample iter: 564
# Sample iter: 565
# Sample iter: 566
# Sample iter: 567
# Sample iter: 568
# Sample iter: 569
# Sample iter: 570
# Sample iter: 571
# Sample iter: 572
# Sample iter: 573
# Sample iter: 574
# Sample iter: 575
# Sample iter: 576
# Sample iter: 577
# Sample iter: 578
# Sample iter: 579
# Sample iter: 580
# Sample iter: 581
# Sample iter: 582
# Sample iter: 583
# Sample iter: 584
# Sample iter: 585
# Sample iter: 586
# Sample iter: 587
# Sample iter: 588
# Sample iter: 589
# Sample iter: 590
# Sample iter: 591
# Sample iter: 592
# Sample iter: 593
# Sample iter: 594
# Sample iter: 595
# Sample iter: 596
# Sample iter: 597
# Sample iter: 598
# Sample iter: 599
# Sample iter: 600
# Sample iter: 601
# Sample iter: 602
# Sample iter: 603
# Sample iter: 604
# Sample iter: 605
# Sample iter: 606
# Sample iter: 607
# Sample iter: 608
# Sample iter: 609
# Sample iter: 610
# Sample iter: 611
# Sample iter: 612
# Sample iter: 613
# Sample iter: 614
# Sample iter: 615
# Sample iter: 616
# Sample iter: 617
# Sample iter: 618
# Sample iter: 619
# Sample iter: 620
# Sample iter: 621
# Sample iter: 622
# Sample iter: 623
# Sample iter: 624
# Sample iter: 625
# Sample iter: 626
# Sample iter: 627
# Sample iter: 628
# Sample iter: 629
# Sample iter: 630
# Sample iter: 631
# Sample iter: 632
# Sample iter: 633
# Sample iter: 634
# Sample iter: 635
# Sample iter: 636
# Sample iter: 637
# Sample iter: 638
# Sample iter: 639
# Sample iter: 640
# Sample iter: 641
# Sample iter: 642
# Sample iter: 643
# Sample iter: 644
# Sample iter: 645
# Sample iter: 646
# Sample iter: 647
# Sample iter: 648
# Sample iter: 649
# Sample iter: 650
# Sample iter: 651
# Sample iter: 652
# Sample iter: 653
# Sample iter: 654
# Sample iter: 655
# Sample iter: 656
# Sample iter: 657
# Sample iter: 658
# Sample iter: 659
# Sample iter: 660
# Sample iter: 661
# Sample iter: 662
# Sample iter: 663
# Sample iter: 664
# Sample iter: 665
# Sample iter: 666
# Sample iter: 667
# Sample iter: 668
# Sample iter: 669
# Sample iter: 670
# Sample iter: 671
# Sample iter: 672
# Sample iter: 673
# Sample iter: 674
# Sample iter: 675
# Sample iter: 676
# Sample iter: 677
# Sample iter: 678
# Sample iter: 679
# Sample iter: 680
# Sample iter: 681
# Sample iter: 682
# Sample iter: 683
# Sample iter: 684
# Sample iter: 685
# Sample iter: 686
# Sample iter: 687
# Sample iter: 688
# Sample iter: 689
# Sample iter: 690
# Sample iter: 691
# Sample iter: 692
# Sample iter: 693
# Sample iter: 694
# Sample iter: 695
# Sample iter: 696
# Sample iter: 697
# Sample iter: 698
# Sample iter: 699
# Sample iter: 700
# Sample iter: 701
# Sample iter: 702
# Sample iter: 703
# Sample iter: 704
# Sample iter: 705
# Sample iter: 706
# Sample iter: 707
# Sample iter: 708
# Sample iter: 709
# Sample iter: 710
# Sample iter: 711
# Sample iter: 712
# Sample iter: 713
# Sample iter: 714
# Sample iter: 715
# Sample iter: 716
# Sample iter: 717
# Sample iter: 718
# Sample iter: 719
# Sample iter: 720
# Sample iter: 721
# Sample iter: 722
# Sample iter: 723
# Sample iter: 724
# Sample iter: 725
# Sample iter: 726
# Sample iter: 727
# Sample iter: 728
# Sample iter: 729
# Sample iter: 730
# Sample iter: 731
# Sample iter: 732
# Sample iter: 733
# Sample iter: 734
# Sample iter: 735
# Sample iter: 736
# Sample iter: 737
# Sample iter: 738
# Sample iter: 739
# Sample iter: 740
# Sample iter: 741
# Sample iter: 742
# Sample iter: 743
# Sample iter: 744
# Sample iter: 745
# Sample iter: 746
# Sample iter: 747
# Sample iter: 748
# Sample iter: 749
# Sample iter: 750
# Sample iter: 751
# Sample iter: 752
# Sample iter: 753
# Sample iter: 754
# Sample iter: 755
# Sample iter: 756
# Sample iter: 757
# Sample iter: 758
# Sample iter: 759
# Sample iter: 760
# Sample iter: 761
# Sample iter: 762
# Sample iter: 763
# Sample iter: 764
# Sample iter: 765
# Sample iter: 766
# Sample iter: 767
# Sample iter: 768
# Sample iter: 769
# Sample iter: 770
# Sample iter: 771
# Sample iter: 772
# Sample iter: 773
# Sample iter: 774
# Sample iter: 775
# Sample iter: 776
# Sample iter: 777
# Sample iter: 778
# Sample iter: 779
# Sample iter: 780
# Sample iter: 781
# Sample iter: 782
# Sample iter: 783
# Sample iter: 784
# Sample iter: 785
# Sample iter: 786
# Sample iter: 787
# Sample iter: 788
# Sample iter: 789
# Sample iter: 790
# Sample iter: 791
# Sample iter: 792
# Sample iter: 793
# Sample iter: 794
# Sample iter: 795
# Sample iter: 796
# Sample iter: 797
# Sample iter: 798
# Sample iter: 799
# Sample iter: 800
# Sample iter: 801
# Sample iter: 802
# Sample iter: 803
# Sample iter: 804
# Sample iter: 805
# Sample iter: 806
# Sample iter: 807
# Sample iter: 808
# Sample iter: 809
# Sample iter: 810
# Sample iter: 811
# Sample iter: 812
# Sample iter: 813
# Sample iter: 814
# Sample iter: 815
# Sample iter: 816
# Sample iter: 817
# Sample iter: 818
# Sample iter: 819
# Sample iter: 820
# Sample iter: 821
# Sample iter: 822
# Sample iter: 823
# Sample iter: 824
# Sample iter: 825
# Sample iter: 826
# Sample iter: 827
# Sample iter: 828
# Sample iter: 829
# Sample iter: 830
# Sample iter: 831
# Sample iter: 832
# Sample iter: 833
# Sample iter: 834
# Sample iter: 835
# Sample iter: 836
# Sample iter: 837
# Sample iter: 838
# Sample iter: 839
# Sample iter: 840
# Sample iter: 841
# Sample iter: 842
# Sample iter: 843
# Sample iter: 844
# Sample iter: 845
# Sample iter: 846
# Sample iter: 847
# Sample iter: 848
# Sample iter: 849
# Sample iter: 850
# Sample iter: 851
# Sample iter: 852
# Sample iter: 853
# Sample iter: 854
# Sample iter: 855
# Sample iter: 856
# Sample iter: 857
# Sample iter: 858
# Sample iter: 859
# Sample iter: 860
# Sample iter: 861
# Sample iter: 862
# Sample iter: 863
# Sample iter: 864
# Sample iter: 865
# Sample iter: 866
# Sample iter: 867
# Sample iter: 868
# Sample iter: 869
# Sample iter: 870
# Sample iter: 871
# Sample iter: 872
# Sample iter: 873
# Sample iter: 874
# Sample iter: 875
# Sample iter: 876
# Sample iter: 877
# Sample iter: 878
# Sample iter: 879
# Sample iter: 880
# Sample iter: 881
# Sample iter: 882
# Sample iter: 883
# Sample iter: 884
# Sample iter: 885
# Sample iter: 886
# Sample iter: 887
# Sample iter: 888
# Sample iter: 889
# Sample iter: 890
# Sample iter: 891
# Sample iter: 892
# Sample iter: 893
# Sample iter: 894
# Sample iter: 895
# Sample iter: 896
# Sample iter: 897
# Sample iter: 898
# Sample iter: 899
# Sample iter: 900
# Sample iter: 901
# Sample iter: 902
# Sample iter: 903
# Sample iter: 904
# Sample iter: 905
# Sample iter: 906
# Sample iter: 907
# Sample iter: 908
# Sample iter: 909
# Sample iter: 910
# Sample iter: 911
# Sample iter: 912
# Sample iter: 913
# Sample iter: 914
# Sample iter: 915
# Sample iter: 916
# Sample iter: 917
# Sample iter: 918
# Sample iter: 919
# Sample iter: 920
# Sample iter: 921
# Sample iter: 922
# Sample iter: 923
# Sample iter: 924
# Sample iter: 925
# Sample iter: 926
# Sample iter: 927
# Sample iter: 928
# Sample iter: 929
# Sample iter: 930
# Sample iter: 931
# Sample iter: 932
# Sample iter: 933
# Sample iter: 934
# Sample iter: 935
# Sample iter: 936
# Sample iter: 937
# Sample iter: 938
# Sample iter: 939
# Sample iter: 940
# Sample iter: 941
# Sample iter: 942
# Sample iter: 943
# Sample iter: 944
# Sample iter: 945
# Sample iter: 946
# Sample iter: 947
# Sample iter: 948
# Sample iter: 949
# Sample iter: 950
# Sample iter: 951
# Sample iter: 952
# Sample iter: 953
# Sample iter: 954
# Sample iter: 955
# Sample iter: 956
# Sample iter: 957
# Sample iter: 958
# Sample iter: 959
# Sample iter: 960
# Sample iter: 961
# Sample iter: 962
# Sample iter: 963
# Sample iter: 964
# Sample iter: 965
# Sample iter: 966
# Sample iter: 967
# Sample iter: 968
# Sample iter: 969
# Sample iter: 970
# Sample iter: 971
# Sample iter: 972
# Sample iter: 973
# Sample iter: 974
# Sample iter: 975
# Sample iter: 976
# Sample iter: 977
# Sample iter: 978
# Sample iter: 979
# Sample iter: 980
# Sample iter: 981
# Sample iter: 982
# Sample iter: 983
# Sample iter: 984
# Sample iter: 985
# Sample iter: 986
# Sample iter: 987
# Sample iter: 988
# Sample iter: 989
# Sample iter: 990
# Sample iter: 991
# Sample iter: 992
# Sample iter: 993
# Sample iter: 994
# Sample iter: 995
# Sample iter: 996
# Sample iter: 997
# Sample iter: 998
# Sample iter: 999
# Sample iter: 1000

# %% [markdown]
# ### Visualization

# %%
chain = sampler.samples
print(chain[1])
# plotting
mean_U = np.mean([i[0][0][0] for i in chain if i[1]], axis=0)
# mean_U = chain[499][0][0]
print(mean_U)
kreg.U.data = torch.from_numpy(mean_U)
# mean_logsn = np.mean([i[0][0][1] for i in chain if i[1]], axis=0)
# kreg.logsn.data = torch.from_numpy(mean_logsn)
xode = odeint(kreg, x0, t).detach().numpy()
# U = kreg.U.detach().numpy()
U = mean_U
Z = kreg.Z.detach().numpy()
xode = np.transpose(xode,[1,0,2])

cols = ['r','b','g','m','c','k']
plt.figure(1,[7,10])
plt.scatter(Z[:,0],Z[:,1],100, facecolors='none', edgecolors='k')
plt.quiver(Z[:,0],Z[:,1],U[:,0],U[:,1],units='height',width=0.006,color='k')
for i in range(min(6,xode.shape[0])):
    plt.plot(X[i,:,0],X[i,:,1],'o',color=cols[i])
    plt.plot(xode[i,:,0],xode[i,:,1],'-',color=cols[i])
# Out:
# ([[array([[ 1.65437344e-02,  6.07589315e+00],
#        [-1.03537172e+00,  4.64313439e+00],
#        [ 3.81433718e-03,  2.70945737e+00],
#        [ 5.13662618e-01, -5.56915784e-01],
#        [ 8.60917725e-02, -1.08517809e+00],
#        [ 5.20804968e-02, -6.47451739e-01],
#        [-1.48981410e+00,  7.52551363e+00],
#        [-1.38703904e+00,  5.32860396e+00],
#        [-4.54598617e-01,  2.90981651e+00],
#        [ 1.32718258e+00, -1.17748874e+00],
#        [ 2.03619909e+00, -1.88020759e+00],
#        [ 6.84262437e-01, -1.73664759e+00],
#        [-3.39906131e+00,  1.52273041e+00],
#        [-1.89778374e+00,  1.19233427e+00],
#        [-1.63268740e-01,  7.85292501e-01],
#        [ 9.63078761e-01,  1.30839589e+00],
#        [ 2.71515412e+00,  1.78150599e+00],
#        [ 1.20714126e+00,  1.69167093e+00],
#        [-5.85036354e-01, -2.00516634e+00],
#        [-2.00183094e+00, -2.40330855e+00],
#        [ 6.06184485e-02,  2.55406955e-01],
#        [ 5.24410676e-01,  1.07939565e+00],
#        [ 2.26371781e+00,  2.01452613e+00],
#        [ 4.49478339e+00,  6.50243482e-01],
#        [ 5.65661150e-01,  2.31369926e-01],
#        [-1.63340992e+00, -5.51869594e-01],
#        [-2.66378729e-01, -9.48239649e-01],
#        [ 1.23982049e+00, -3.17132117e+00],
#        [ 2.28125661e+00, -3.62601420e+00],
#        [ 3.84365289e+00, -4.77729861e+00],
#        [-1.99294203e-01,  6.86374639e-01],
#        [-2.80232426e-01,  1.34387655e+00],
#        [-5.24408537e-01,  1.18152068e-01],
#        [ 6.49025273e-01, -3.72229414e+00],
#        [ 6.38665533e-01, -4.60857945e+00],
#        [ 1.26677560e+00, -3.43877097e+00]])]], True)
# [[ 0.03656183  5.98213814]
#  [-1.04462858  4.46414257]
#  [ 0.05651671  2.8784946 ]
#  [ 0.76151811 -1.01686585]
#  [ 0.12666003 -0.77067198]
#  [-0.32510916 -0.45048992]
#  [-1.46936311  7.01755101]
#  [-1.46408674  5.27839474]
#  [-0.30936277  3.00234635]
#  [ 1.07653829 -0.93797282]
#  [ 2.15863675 -2.38727467]
#  [ 0.70657329 -1.13722748]
#  [-3.15318242  1.55683988]
#  [-2.11327833  1.13630821]
#  [-0.45099704  0.75645256]
#  [ 0.84167333  1.34057389]
#  [ 2.80707931  1.72050254]
#  [ 1.44611598  1.73896493]
#  [-0.95778313 -1.5607813 ]
#  [-1.77955049 -2.00782123]
#  [-0.11519978 -0.0660577 ]
#  [ 0.60348903  0.65405857]
#  [ 2.60330135  1.74421008]
#  [ 4.2454498   0.71865355]
#  [ 0.64518842  0.10810073]
#  [-1.21606111 -0.80580216]
#  [-0.31165687 -0.93206483]
#  [ 1.13235192 -3.26045432]
#  [ 2.289136   -3.15471946]
#  [ 3.69275159 -4.98783742]
#  [-0.02860946  0.56521614]
#  [-0.34388836  1.13033376]
#  [-0.56860072 -0.02563664]
#  [ 0.39303478 -3.56856191]
#  [ 0.5249038  -4.09914603]
#  [ 0.7703087  -3.99264805]]

# %%
plt.plot(logp_array)

# %%
# [sample[0][0][0][0][0] for sample in chain if sample[1]]
plt.plot([sample[0][0][0][10][1] for sample in chain[0:1000:10] if sample[1]])

# %%
hess = hess_closure()
